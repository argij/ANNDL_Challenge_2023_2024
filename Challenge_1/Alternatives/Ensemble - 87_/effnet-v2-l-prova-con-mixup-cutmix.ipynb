# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Fix randomness and hide warnings
seed = 164

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# Import tensorflow
import tensorflow as tf

from tensorflow import keras as tfk
from keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)

# Import other libraries
import cv2
from keras.applications.efficientnet_v2 import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import seaborn as sns
from PIL import Image
import pandas as pd
# Out:
# 2.13.0

# %%
data = np.load('/kaggle/input/challenge/dataset_refined.npz', allow_pickle=True)

images = data['arr_0']
labels = data['arr_1']
labels = np.array(labels)
images = np.array(images)

# %%
from imblearn.over_sampling import SMOTE


# Assuming you have a dataset with features 'images' and labels 'labels'

# Initialize the SMOTE object
smote = SMOTE(sampling_strategy=0.75, random_state=seed)

# Flatten the images
images_flat = images.reshape(images.shape[0], -1)  # Reshape to (num_samples, num_features)

# Now you can use SMOTE on 'images_flat'
images_smote, labels_smote = smote.fit_resample(images_flat, labels)


# Now, 'images_smote' and 'labels_smote' contain the oversampled dataset

#reshape the images

original_shape = (96, 96, 3)

images_original_shape = images_smote.reshape(-1, *original_shape)

# %%
#just for clarity
images_balanced = images_original_shape
labels_balanced = labels_smote

# %%
#SHow the data
# Number of images to display
size = labels_balanced.size
num_img = 10
# Create a random index to display every time a different set of images
random_index = np.random.rand()
random_index = int(random_index*(size-num_img))

# Create subplots for displaying items
fig, axes = plt.subplots(2, num_img//2, figsize=(20, 9))
for i in range(random_index, random_index + num_img):
    title = 'true label: ' + str(labels_balanced[i]) + ' index: ' + str(i)
    ax = axes[i%2, i%num_img//2]
    ax.set_title(title)
    ax.imshow(np.clip(images_balanced[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
print('Dataset campionato: ' + str(labels_balanced.size))
print('Dataset originale: ' + str(labels.size))
counts, unique = np.unique(labels_balanced, return_counts = True)
for i in range(counts.size):
  print(counts[i] + ': ' + str(unique[i]))
# Out:
# Dataset campionato: 5355
# Dataset originale: 4850
# healthy: 3060
# unhealthy: 2295

# %% [markdown]
# augmentation

# %%
# Assuming 'labels_balanced' is a NumPy array containing your categorical labels
labels_onehot = labels_balanced  # Replace with your actual labels

# Get the unique categories in your label array
unique_categories = np.unique(labels_onehot)

# Initialize an empty array for one-hot encoded labels
one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

# Create one-hot encoded labels
for i, category in enumerate(unique_categories):
    one_hot_labels[:, i] = (labels_onehot == category).astype(int)

# Now, 'one_hot_labels' contains the one-hot encoded labels

labels_balanced_onehot = one_hot_labels

# %%
# Define a function to perform MixUp on the dataset
def mixup_data(X, y, alpha=0.2):
    mixed_X = []
    mixed_y = []

    for i in range(len(X)):
        # Randomly select another sample to mix with
        j = np.random.randint(len(X))

        # Randomly select a mixing ratio from a beta distribution
        beta = np.random.beta(alpha, alpha)

        mixed_X.append((X[i] * beta) + (X[j] * (1 - beta)))
        mixed_y.append((y[i] * beta) + (y[j] * (1 - beta)))

    mixed_X = np.array(mixed_X)
    mixed_y = np.array(mixed_y)

    return mixed_X, mixed_y

# Perform MixUp on your training data
images_augmented, labels_augmented_onehot = mixup_data(images_balanced, labels_balanced_onehot, alpha=0.5)

# %%
#PREPARE FOR NEXT LAYER
labels_augmented = labels_augmented_onehot
images_augmented = images_augmented

# %%
def cutmix(images, labels, beta=1.0):
    """
    Apply CutMix data augmentation to a dataset.

    Args:
    images (numpy.ndarray): An array of images with shape (num_samples, height, width, channels).
    labels (numpy.ndarray): An array of labels with shape (num_samples, num_classes).
    beta (float): CutMix hyperparameter (default is 1.0).

    Returns:
    mixed_images (numpy.ndarray): Mixed images.
    mixed_labels (numpy.ndarray): Mixed labels.
    """
    num_samples, height, width, channels = images.shape

    # Randomly choose another sample to cut and mix with
    indices = np.arange(num_samples)
    np.random.shuffle(indices)
    mixed_images = images.copy()
    mixed_labels = labels.copy()

    for i in range(num_samples):
        j = indices[i]
        lam = np.random.beta(beta, beta)
        x, y, h, w = get_random_bbox(width, height, lam)
        mixed_images[i, y:y+h, x:x+w, :] = images[j, y:y+h, x:x+w, :]
        lam = 1 - (w * h / (width * height))
        mixed_labels[i] = lam * labels[i] + (1 - lam) * labels[j]

    return mixed_images, mixed_labels

def get_random_bbox(width, height, lam):
    r_x = np.random.randint(width)
    r_y = np.random.randint(height)
    r_w = int(width * np.sqrt(1 - lam))
    r_h = int(height * np.sqrt(1 - lam))
    x1 = np.clip(r_x - r_w // 2, 0, width)
    y1 = np.clip(r_y - r_h // 2, 0, height)
    x2 = np.clip(r_x + r_w // 2, 0, width)
    y2 = np.clip(r_y + r_h // 2, 0, height)
    return x1, y1, x2 - x1, y2 - y1

# Example usage:
# Assuming 'images' is your image dataset and 'labels' are the corresponding labels
images_augmented_tot, labels_augmented_onehot_tot = cutmix(images_augmented, labels_augmented, beta=1.5)

# %%
#PREPARE FOR NEXT LAYER
labels_augmented = labels_augmented_onehot_tot
images_augmented = images_augmented_tot

# %%
from sklearn.utils import shuffle
# Concatenate the original dataset with the mixup dataset
augmented_images_conc = np.concatenate((images_balanced, images_augmented), axis=0)
augmented_labels_conc = np.concatenate((labels_balanced_onehot, labels_augmented), axis=0)

# Shuffle the concatenated dataset
augmented_images_conc, augmented_labels_conc = shuffle(augmented_images_conc, augmented_labels_conc, random_state=seed)

#to make sure the next blocks work
images_augmented = augmented_images_conc
labels_augmented = augmented_labels_conc

# %%
if labels_augmented.ndim == 1:
  print("eseguendo onehot\n")

  # Assuming 'labels_balanced' is a NumPy array containing your categorical labels
  labels_onehot = labels_augmented  # Replace with your actual labels

  # Get the unique categories in your label array
  unique_categories = np.unique(labels_onehot)

  # Initialize an empty array for one-hot encoded labels
  one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

  # Create one-hot encoded labels
  for i, category in enumerate(unique_categories):
     one_hot_labels[:, i] = (labels_onehot == category).astype(int)

  # Now, 'one_hot_labels' contains the one-hot encoded labels

  labels_augmented_onehot = one_hot_labels


else:
  print("one-hot già eseguito\n")

  labels_augmented_onehot = labels_augmented
# Out:
# one-hot già eseguito

# %%
#remember to call the results of the previous section X (processed dataset) and y (one hot encoded labels)
X = images_augmented
y = labels_augmented
# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=.15, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=.10, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (8192, 96, 96, 3), y_train shape: (8192, 2)
# X_val shape: (911, 96, 96, 3), y_val shape: (911, 2)
# X_test shape: (1607, 96, 96, 3), y_test shape: (1607, 2)

# %% [markdown]
# Efficient net transfer learning

# %%
#EfficientNetV2L
efficientnet = tfk.applications.EfficientNetV2L(
    include_top=False,
    weights="imagenet",
    pooling='avg',
    classes=2,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 [==============================] - 14s 0us/step

# %%
from tensorflow.keras.regularizers import l2

def build_efficientnet():

# Use the supernet as feature extractor, i.e. freeze all its weigths
    efficientnet.trainable = False

# Create an input layer with shape (96, 96, 3)
    inputs = tfk.Input(shape=(96, 96, 3))

# Connect MobileNetV2 to the input
    x = efficientnet(inputs)

#Hyperparameters obtained using the tuner library
# Dense layer with regularizer between mobile net and batch
  #x = tfkl.Dense(units=hp.Int("units", min_value=32, max_value=512, step=32),
                 #kernel_regularizer=l2(0.01))(x)
    x = tfkl.Dense(1280, activation='relu')(x)
#x = tfkl.Dense(1280, activation='relu')(x)

# Add Batch Normalization
    x = tfkl.BatchNormalization(epsilon=1e-06, momentum=0.9, weights=None)(x)
    x = tfkl.Dropout(0.5)(x)

# Dense layer between batch and dropout with regularizer
    x = tfkl.Dense(640, activation='relu')(x)
#x = tfkl.Dense(640, activation='relu')(x)

# Add a Dropout layer with 0.4
    x = tfkl.BatchNormalization(epsilon=1e-06, momentum=0.9, weights=None)(x)
    x = tfkl.Dropout(0.5)(x)

# Add a Dense layer with 2 units and softmax activation as the classifier
    outputs = tfkl.Dense(2, activation='softmax')(x)

# Create a Model connecting input and output
    tl2_model = tfk.Model(inputs=inputs, outputs=outputs, name='model_efficientnet')


    return tl2_model

# %%
tl2_model = build_efficientnet()
# Compile the model with Categorical Cross-Entropy loss and Adam optimizer
tl2_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])

# %%
# Train the model
# Batch size = 30, dropout layer = 0.4, inputs are denormalized since we need to apply the preprocessing thought for MobileNet
history = tl2_model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    #sample_weight = weights,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)]
).history
# Out:
# Epoch 1/200
# 512/512 [==============================] - 65s 63ms/step - loss: 0.8241 - accuracy: 0.6331 - val_loss: 0.5219 - val_accuracy: 0.7574 - lr: 0.0010
# Epoch 2/200
# 512/512 [==============================] - 23s 46ms/step - loss: 0.6340 - accuracy: 0.6809 - val_loss: 0.5231 - val_accuracy: 0.7607 - lr: 0.0010
# Epoch 3/200
# 512/512 [==============================] - 23s 46ms/step - loss: 0.6023 - accuracy: 0.7115 - val_loss: 0.5057 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 4/200
# 512/512 [==============================] - 23s 45ms/step - loss: 0.5837 - accuracy: 0.7169 - val_loss: 0.5198 - val_accuracy: 0.7541 - lr: 0.0010
# Epoch 5/200
# 512/512 [==============================] - 23s 46ms/step - loss: 0.5856 - accuracy: 0.7158 - val_loss: 0.4829 - val_accuracy: 0.7936 - lr: 0.0010
# Epoch 6/200
# 512/512 [==============================] - 23s 44ms/step - loss: 0.5791 - accuracy: 0.7230 - val_loss: 0.4990 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 7/200
# 512/512 [==============================] - 23s 46ms/step - loss: 0.5733 - accuracy: 0.7262 - val_loss: 0.4853 - val_accuracy: 0.8090 - lr: 0.0010
# Epoch 8/200
# 512/512 [==============================] - 23s 45ms/step - loss: 0.5636 - accuracy: 0.7314 - val_loss: 0.5408 - val_accuracy: 0.7322 - lr: 0.0010
# Epoch 9/200
# 512/512 [==============================] - 23s 44ms/step - loss: 0.5751 - accuracy: 0.7164 - val_loss: 0.4798 - val_accuracy: 0.7849 - lr: 0.0010
# Epoch 10/200
# 512/512 [==============================] - 23s 44ms/step - loss: 0.5660 - accuracy: 0.7340 - val_loss: 0.4776 - val_accuracy: 0.8079 - lr: 0.0010
# Epoch 11/200
# 512/512 [==============================] - 23s 44ms/step - loss: 0.5683 - accuracy: 0.7329 - val_loss: 0.4740 - val_accuracy: 0.7980 - lr: 0.0010
# Epoch 12/200
# 512/512 [==============================] - 23s 44ms/step - loss: 0.5594 - accuracy: 0.7323 - val_loss: 0.4801 - val_accuracy: 0.7991 - lr: 0.0010
# Epoch 13/200
# 512/512 [==============================] - 23s 44ms/step - loss: 0.5613 - accuracy: 0.7310 - val_loss: 0.4940 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 14/200
# 512/512 [==============================] - 23s 44ms/step - loss: 0.5552 - accuracy: 0.7358 - val_loss: 0.4902 - val_accuracy: 0.7772 - lr: 0.0010
# Epoch 15/200
# 512/512 [==============================] - 23s 44ms/step - loss: 0.5507 - accuracy: 0.7423 - val_loss: 0.4730 - val_accuracy: 0.7914 - lr: 0.0010
# Epoch 16/200
# 512/512 [==============================] - 23s 44ms/step - loss: 0.5512 - accuracy: 0.7407 - val_loss: 0.4742 - val_accuracy: 0.8002 - lr: 0.0010
# Epoch 17/200
# 512/512 [==============================] - 24s 47ms/step - loss: 0.5430 - accuracy: 0.7473 - val_loss: 0.4844 - val_accuracy: 0.7783 - lr: 0.0010

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='EfficientNet V2 L Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='EfficientNet V2 L Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
tl2_model.save('/kaggle/working/TransferLearningModelEfficientNetL')

# %%
# Predict labels for the entire test set (augmented)
X_test = preprocess_input(X_test*255)
predictions = tl2_model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(('healthy','unhealthy')), yticklabels=list(('healthy','unhealthy')), cmap='Blues', annot=True)
plt.title('Predictions of the augmented test set')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (1607, 2)
# Accuracy: 0.7729
# Precision: 0.7675
# Recall: 0.767
# F1: 0.7672

# %%
# Re-load the model after transfer learning
ft2_model = tf.keras.models.load_model('/kaggle/working/TransferLearningModelEfficientNetL')
del tl2_model

#ft2_model = build_efficientnet()
ft2_model.summary()

# Set all MobileNetV2 layers as trainable
ft2_model.get_layer('efficientnetv2-l').trainable = True
# Out:
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-l (Function  (None, 1280)              117746848
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  batch_normalization_1 (Bat  (None, 640)               2560
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 120215330 (458.59 MB)
# Trainable params: 2464642 (9.40 MB)
# Non-trainable params: 117750688 (449.18 MB)
# _________________________________________________________________

# %%
# Freeze first N layers, e.g., until the 133rd one
#meno layer??
#N = 71
N = 526
for i, layer in enumerate(ft2_model.get_layer('efficientnetv2-l').layers[:N]):
  layer.trainable=False
ft2_model.summary()

ft2_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-5), metrics=['accuracy'])
# Out:
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-l (Function  (None, 1280)              117746848
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  batch_normalization_1 (Bat  (None, 640)               2560
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 120215330 (458.59 MB)
# Trainable params: 99408650 (379.21 MB)
# Non-trainable params: 20806680 (79.37 MB)
# _________________________________________________________________

# %%
# Fine-tune the model
history = ft2_model.fit(
    x = preprocess_input(X_train*255), 
    y = y_train,
    #sample_weight = weights,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val), 
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True),
                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)]
).history
# Out:
# Epoch 1/200
# 512/512 [==============================] - 157s 118ms/step - loss: 0.6155 - accuracy: 0.6925 - val_loss: 0.4914 - val_accuracy: 0.7838 - lr: 1.0000e-05
# Epoch 2/200
# 512/512 [==============================] - 54s 105ms/step - loss: 0.5203 - accuracy: 0.7599 - val_loss: 0.4588 - val_accuracy: 0.7936 - lr: 1.0000e-05
# Epoch 3/200
# 512/512 [==============================] - 54s 105ms/step - loss: 0.4673 - accuracy: 0.7983 - val_loss: 0.4399 - val_accuracy: 0.8046 - lr: 1.0000e-05
# Epoch 4/200
# 512/512 [==============================] - 54s 105ms/step - loss: 0.4348 - accuracy: 0.8212 - val_loss: 0.4257 - val_accuracy: 0.8244 - lr: 1.0000e-05
# Epoch 5/200
# 512/512 [==============================] - 55s 108ms/step - loss: 0.4021 - accuracy: 0.8434 - val_loss: 0.4215 - val_accuracy: 0.8342 - lr: 1.0000e-05
# Epoch 6/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.3731 - accuracy: 0.8672 - val_loss: 0.4270 - val_accuracy: 0.8189 - lr: 1.0000e-05
# Epoch 7/200
# 512/512 [==============================] - 55s 108ms/step - loss: 0.3558 - accuracy: 0.8761 - val_loss: 0.4192 - val_accuracy: 0.8474 - lr: 1.0000e-05
# Epoch 8/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.3497 - accuracy: 0.8804 - val_loss: 0.4353 - val_accuracy: 0.8244 - lr: 1.0000e-05
# Epoch 9/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.3404 - accuracy: 0.8806 - val_loss: 0.4137 - val_accuracy: 0.8408 - lr: 1.0000e-05
# Epoch 10/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.3319 - accuracy: 0.8903 - val_loss: 0.4196 - val_accuracy: 0.8430 - lr: 1.0000e-05
# Epoch 11/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.3191 - accuracy: 0.8960 - val_loss: 0.4169 - val_accuracy: 0.8364 - lr: 1.0000e-05
# Epoch 12/200
# 512/512 [==============================] - 55s 108ms/step - loss: 0.3191 - accuracy: 0.8962 - val_loss: 0.4081 - val_accuracy: 0.8485 - lr: 1.0000e-05
# Epoch 13/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.3077 - accuracy: 0.9030 - val_loss: 0.4009 - val_accuracy: 0.8485 - lr: 1.0000e-05
# Epoch 14/200
# 512/512 [==============================] - 56s 109ms/step - loss: 0.3001 - accuracy: 0.9149 - val_loss: 0.4052 - val_accuracy: 0.8518 - lr: 1.0000e-05
# Epoch 15/200
# 512/512 [==============================] - 56s 109ms/step - loss: 0.2939 - accuracy: 0.9106 - val_loss: 0.3877 - val_accuracy: 0.8562 - lr: 1.0000e-05
# Epoch 16/200
# 512/512 [==============================] - 55s 108ms/step - loss: 0.2922 - accuracy: 0.9120 - val_loss: 0.3911 - val_accuracy: 0.8606 - lr: 1.0000e-05
# Epoch 17/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.2938 - accuracy: 0.9095 - val_loss: 0.4065 - val_accuracy: 0.8507 - lr: 1.0000e-05
# Epoch 18/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.2893 - accuracy: 0.9183 - val_loss: 0.3975 - val_accuracy: 0.8540 - lr: 1.0000e-05
# Epoch 19/200
# 512/512 [==============================] - 55s 108ms/step - loss: 0.2895 - accuracy: 0.9146 - val_loss: 0.4119 - val_accuracy: 0.8540 - lr: 1.0000e-05
# Epoch 20/200
# 512/512 [==============================] - 56s 109ms/step - loss: 0.2863 - accuracy: 0.9178 - val_loss: 0.3851 - val_accuracy: 0.8650 - lr: 1.0000e-05
# Epoch 21/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.2842 - accuracy: 0.9166 - val_loss: 0.4026 - val_accuracy: 0.8529 - lr: 1.0000e-05
# Epoch 22/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.2834 - accuracy: 0.9213 - val_loss: 0.3867 - val_accuracy: 0.8584 - lr: 1.0000e-05
# Epoch 23/200
# 512/512 [==============================] - 55s 108ms/step - loss: 0.2812 - accuracy: 0.9215 - val_loss: 0.3835 - val_accuracy: 0.8606 - lr: 1.0000e-05
# Epoch 24/200
# 512/512 [==============================] - 56s 109ms/step - loss: 0.2772 - accuracy: 0.9269 - val_loss: 0.3830 - val_accuracy: 0.8661 - lr: 1.0000e-05
# Epoch 25/200
# 512/512 [==============================] - 56s 109ms/step - loss: 0.2740 - accuracy: 0.9241 - val_loss: 0.3801 - val_accuracy: 0.8749 - lr: 1.0000e-05
# Epoch 26/200
# 512/512 [==============================] - 55s 108ms/step - loss: 0.2775 - accuracy: 0.9210 - val_loss: 0.3859 - val_accuracy: 0.8617 - lr: 1.0000e-05
# Epoch 27/200
# 512/512 [==============================] - 56s 109ms/step - loss: 0.2709 - accuracy: 0.9261 - val_loss: 0.3698 - val_accuracy: 0.8760 - lr: 1.0000e-05
# Epoch 28/200
# 512/512 [==============================] - 55s 108ms/step - loss: 0.2711 - accuracy: 0.9221 - val_loss: 0.3702 - val_accuracy: 0.8661 - lr: 1.0000e-05
# Epoch 29/200
# 512/512 [==============================] - 56s 109ms/step - loss: 0.2704 - accuracy: 0.9285 - val_loss: 0.3779 - val_accuracy: 0.8782 - lr: 1.0000e-05
# Epoch 30/200
# 512/512 [==============================] - 55s 107ms/step - loss: 0.2710 - accuracy: 0.9238 - val_loss: 0.3763 - val_accuracy: 0.8749 - lr: 1.0000e-05
# Epoch 31/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2642 - accuracy: 0.9298 - val_loss: 0.3883 - val_accuracy: 0.8672 - lr: 1.0000e-05
# Epoch 32/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2628 - accuracy: 0.9285 - val_loss: 0.3804 - val_accuracy: 0.8793 - lr: 1.0000e-05
# Epoch 33/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2613 - accuracy: 0.9326 - val_loss: 0.3888 - val_accuracy: 0.8683 - lr: 1.0000e-06
# Epoch 34/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2592 - accuracy: 0.9358 - val_loss: 0.3755 - val_accuracy: 0.8716 - lr: 1.0000e-06
# Epoch 35/200
# 512/512 [==============================] - 53s 104ms/step - loss: 0.2589 - accuracy: 0.9313 - val_loss: 0.3770 - val_accuracy: 0.8771 - lr: 1.0000e-06
# Epoch 36/200
# 512/512 [==============================] - 53s 104ms/step - loss: 0.2608 - accuracy: 0.9248 - val_loss: 0.3703 - val_accuracy: 0.8782 - lr: 1.0000e-06
# Epoch 37/200
# 512/512 [==============================] - 53s 104ms/step - loss: 0.2567 - accuracy: 0.9353 - val_loss: 0.3738 - val_accuracy: 0.8727 - lr: 1.0000e-06
# Epoch 38/200
# 512/512 [==============================] - 53s 104ms/step - loss: 0.2571 - accuracy: 0.9347 - val_loss: 0.3707 - val_accuracy: 0.8814 - lr: 1.0000e-07
# Epoch 39/200
# 512/512 [==============================] - 53s 104ms/step - loss: 0.2555 - accuracy: 0.9363 - val_loss: 0.3748 - val_accuracy: 0.8814 - lr: 1.0000e-07
# Epoch 40/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2555 - accuracy: 0.9320 - val_loss: 0.3891 - val_accuracy: 0.8606 - lr: 1.0000e-07
# Epoch 41/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2512 - accuracy: 0.9368 - val_loss: 0.3785 - val_accuracy: 0.8716 - lr: 1.0000e-07
# Epoch 42/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2538 - accuracy: 0.9313 - val_loss: 0.3728 - val_accuracy: 0.8782 - lr: 1.0000e-07
# Epoch 43/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2578 - accuracy: 0.9355 - val_loss: 0.3759 - val_accuracy: 0.8793 - lr: 1.0000e-08
# Epoch 44/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2557 - accuracy: 0.9375 - val_loss: 0.3793 - val_accuracy: 0.8771 - lr: 1.0000e-08
# Epoch 45/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2554 - accuracy: 0.9316 - val_loss: 0.3780 - val_accuracy: 0.8771 - lr: 1.0000e-08
# Epoch 46/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2629 - accuracy: 0.9313 - val_loss: 0.3805 - val_accuracy: 0.8749 - lr: 1.0000e-08
# Epoch 47/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2591 - accuracy: 0.9290 - val_loss: 0.3716 - val_accuracy: 0.8825 - lr: 1.0000e-08
# Epoch 48/200
# 512/512 [==============================] - 52s 103ms/step - loss: 0.2536 - accuracy: 0.9395 - val_loss: 0.3804 - val_accuracy: 0.8705 - lr: 1.0000e-09
# Epoch 49/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2544 - accuracy: 0.9315 - val_loss: 0.3751 - val_accuracy: 0.8782 - lr: 1.0000e-09
# Epoch 50/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2546 - accuracy: 0.9335 - val_loss: 0.3732 - val_accuracy: 0.8793 - lr: 1.0000e-09
# Epoch 51/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2535 - accuracy: 0.9371 - val_loss: 0.3791 - val_accuracy: 0.8771 - lr: 1.0000e-09
# Epoch 52/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2564 - accuracy: 0.9343 - val_loss: 0.3820 - val_accuracy: 0.8727 - lr: 1.0000e-09
# Epoch 53/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2582 - accuracy: 0.9331 - val_loss: 0.3751 - val_accuracy: 0.8825 - lr: 1.0000e-10
# Epoch 54/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2534 - accuracy: 0.9347 - val_loss: 0.3691 - val_accuracy: 0.8825 - lr: 1.0000e-10
# Epoch 55/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2515 - accuracy: 0.9359 - val_loss: 0.3754 - val_accuracy: 0.8760 - lr: 1.0000e-10
# Epoch 56/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2512 - accuracy: 0.9395 - val_loss: 0.3726 - val_accuracy: 0.8705 - lr: 1.0000e-10
# Epoch 57/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2524 - accuracy: 0.9391 - val_loss: 0.3789 - val_accuracy: 0.8749 - lr: 1.0000e-10
# Epoch 58/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2532 - accuracy: 0.9354 - val_loss: 0.3714 - val_accuracy: 0.8760 - lr: 1.0000e-10
# Epoch 59/200
# 512/512 [==============================] - 53s 104ms/step - loss: 0.2564 - accuracy: 0.9338 - val_loss: 0.3793 - val_accuracy: 0.8836 - lr: 1.0000e-10
# Epoch 60/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2567 - accuracy: 0.9319 - val_loss: 0.3757 - val_accuracy: 0.8705 - lr: 1.0000e-11
# Epoch 61/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2606 - accuracy: 0.9316 - val_loss: 0.3727 - val_accuracy: 0.8727 - lr: 1.0000e-11
# Epoch 62/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2553 - accuracy: 0.9358 - val_loss: 0.3742 - val_accuracy: 0.8793 - lr: 1.0000e-11
# Epoch 63/200
# 512/512 [==============================] - 54s 105ms/step - loss: 0.2578 - accuracy: 0.9308 - val_loss: 0.3723 - val_accuracy: 0.8793 - lr: 1.0000e-11
# Epoch 64/200
# 512/512 [==============================] - 53s 104ms/step - loss: 0.2569 - accuracy: 0.9365 - val_loss: 0.3733 - val_accuracy: 0.8738 - lr: 1.0000e-11
# Epoch 65/200
# 512/512 [==============================] - 53s 104ms/step - loss: 0.2594 - accuracy: 0.9347 - val_loss: 0.3941 - val_accuracy: 0.8683 - lr: 1.0000e-12
# Epoch 66/200
# 512/512 [==============================] - 54s 105ms/step - loss: 0.2578 - accuracy: 0.9326 - val_loss: 0.3782 - val_accuracy: 0.8836 - lr: 1.0000e-12
# Epoch 67/200
# 512/512 [==============================] - 54s 105ms/step - loss: 0.2538 - accuracy: 0.9363 - val_loss: 0.3712 - val_accuracy: 0.8760 - lr: 1.0000e-12
# Epoch 68/200
# 512/512 [==============================] - 54s 105ms/step - loss: 0.2516 - accuracy: 0.9369 - val_loss: 0.3742 - val_accuracy: 0.8760 - lr: 1.0000e-12
# Epoch 69/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2571 - accuracy: 0.9324 - val_loss: 0.3744 - val_accuracy: 0.8727 - lr: 1.0000e-12
# Epoch 70/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2562 - accuracy: 0.9351 - val_loss: 0.3740 - val_accuracy: 0.8804 - lr: 1.0000e-13
# Epoch 71/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2578 - accuracy: 0.9340 - val_loss: 0.3738 - val_accuracy: 0.8804 - lr: 1.0000e-13
# Epoch 72/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2557 - accuracy: 0.9327 - val_loss: 0.3762 - val_accuracy: 0.8738 - lr: 1.0000e-13
# Epoch 73/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2554 - accuracy: 0.9343 - val_loss: 0.3732 - val_accuracy: 0.8793 - lr: 1.0000e-13
# Epoch 74/200
# 512/512 [==============================] - 52s 102ms/step - loss: 0.2547 - accuracy: 0.9363 - val_loss: 0.3715 - val_accuracy: 0.8738 - lr: 1.0000e-13
# Epoch 75/200
# 512/512 [==============================] - 53s 104ms/step - loss: 0.2540 - accuracy: 0.9338 - val_loss: 0.3734 - val_accuracy: 0.8825 - lr: 1.0000e-14
# Epoch 76/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2541 - accuracy: 0.9346 - val_loss: 0.3768 - val_accuracy: 0.8727 - lr: 1.0000e-14
# Epoch 77/200
# 512/512 [==============================] - 53s 103ms/step - loss: 0.2520 - accuracy: 0.9388 - val_loss: 0.3740 - val_accuracy: 0.8716 - lr: 1.0000e-14
# Epoch 78/200
# 512/512 [==============================] - 52s 101ms/step - loss: 0.2562 - accuracy: 0.9321 - val_loss: 0.3779 - val_accuracy: 0.8694 - lr: 1.0000e-14
# Epoch 79/200
# 512/512 [==============================] - 54s 105ms/step - loss: 0.2547 - accuracy: 0.9320 - val_loss: 0.3758 - val_accuracy: 0.8782 - lr: 1.0000e-14

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='EfficientNet V2 L Fine Tuning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='EfficientNet V2 L Fine Tuning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the best model
ft2_model.save('/kaggle/working/FineTuningModelEfficientNetL')

# %%
# Predict labels for the entire test set (augmented)
X_test = preprocess_input(X_test*255)
predictions = ft2_model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(('healthy','unhealthy')), yticklabels=list(('healthy','unhealthy')), cmap='Blues', annot=True)
plt.title('Predictions of the augmented test set')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (1607, 2)
# Accuracy: 0.5283
# Precision: 0.4913
# Recall: 0.493
# F1: 0.4793
