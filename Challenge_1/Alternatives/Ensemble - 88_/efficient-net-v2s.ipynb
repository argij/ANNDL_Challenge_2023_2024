# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/anndl-challenge/dataset_refined.npz

# %%
# Fix randomness and hide warnings
seed = 24

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# Import tensorflow
import tensorflow as tf

from tensorflow import keras as tfk
from keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)

# Import other libraries
import cv2
from keras.applications.efficientnet_v2 import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import seaborn as sns
from PIL import Image
import pandas as pd
# Out:
# 2.13.0

# %%
data = np.load('/kaggle/input/anndl-challenge/dataset_refined.npz', allow_pickle=True)

images = data['arr_0']
labels = data['arr_1']
labels = np.array(labels)
images = np.array(images)

# %%
#SHow the data
# Number of images to display
size = labels.size
num_img = 10
# Create a random index to display every time a different set of images
random_index = np.random.rand()
random_index = int(random_index*(size-num_img))

# Create subplots for displaying items
fig, axes = plt.subplots(2, num_img//2, figsize=(20, 9))
for i in range(random_index, random_index + num_img):
    title = 'true label: ' + str(labels[i]) + ' index: ' + str(i)
    ax = axes[i%2, i%num_img//2]
    ax.set_title(title)
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
from sklearn.utils import resample
# This time we are solving class imbalance using undersampling and not SMOTE
unique_labels, label_counts = np.unique(labels, return_counts=True)
minority_class = unique_labels[np.argmin(label_counts)]
minority_count = np.min(label_counts)

# Find indices of samples belonging to the minority class
minority_indices = np.where(labels == minority_class)[0]

# Find indices of samples belonging to the majority class
majority_indices = np.where(labels != minority_class)[0]

# Randomly undersample the majority class
undersampled_majority_indices = resample(majority_indices, n_samples=minority_count, random_state=42)

# Combine the indices of the minority and undersampled majority class
undersampled_indices = np.concatenate((minority_indices, undersampled_majority_indices))

images_balanced = images[undersampled_indices]
labels_balanced = labels[undersampled_indices]

# %%
# Show the data
# Number of images to display
size = labels_balanced.size
num_img = 10
# Create a random index to display every time a different set of images
random_index = np.random.rand()
random_index = int(random_index*(size-num_img))

# Create subplots for displaying items
fig, axes = plt.subplots(2, num_img//2, figsize=(20, 9))
for i in range(random_index, random_index + num_img):
    title = 'true label: ' + str(labels_balanced[i]) + ' index: ' + str(i)
    ax = axes[i%2, i%num_img//2]
    ax.set_title(title)
    ax.imshow(np.clip(images_balanced[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
print('Dataset campionato: ' + str(labels_balanced.size))
print('Dataset originale: ' + str(labels.size))
counts, unique = np.unique(labels_balanced, return_counts = True)
for i in range(counts.size):
  print(counts[i] + ': ' + str(unique[i]))
# Out:
# Dataset campionato: 3580
# Dataset originale: 4850
# healthy: 1790
# unhealthy: 1790

# %% [markdown]
# augmentation

# %%
# Assuming 'labels_balanced' is a NumPy array containing your categorical labels
labels_onehot = labels_balanced  # Replace with your actual labels

# Get the unique categories in your label array
unique_categories = np.unique(labels_onehot)

# Initialize an empty array for one-hot encoded labels
one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

# Create one-hot encoded labels
for i, category in enumerate(unique_categories):
    one_hot_labels[:, i] = (labels_onehot == category).astype(int)

# Now, 'one_hot_labels' contains the one-hot encoded labels

labels_balanced_onehot = one_hot_labels

# %%
# Define a function to perform MixUp on the dataset
def mixup_data(X, y, alpha=0.2):
    mixed_X = []
    mixed_y = []

    for i in range(len(X)):
        # Randomly select another sample to mix with
        j = np.random.randint(len(X))

        # Randomly select a mixing ratio from a beta distribution
        beta = np.random.beta(alpha, alpha)

        mixed_X.append((X[i] * beta) + (X[j] * (1 - beta)))
        mixed_y.append((y[i] * beta) + (y[j] * (1 - beta)))

    mixed_X = np.array(mixed_X)
    mixed_y = np.array(mixed_y)

    return mixed_X, mixed_y

# Perform MixUp on your training data
images_augmented, labels_augmented_onehot = mixup_data(images_balanced, labels_balanced_onehot, alpha=0.2)

# %%
# Needed for next block
labels_augmented = labels_augmented_onehot
images_augmented = images_augmented

# %%
from sklearn.utils import shuffle
# Concatenate the original dataset with the mixup dataset
augmented_images_conc = np.concatenate((images_balanced, images_augmented), axis=0)
augmented_labels_conc = np.concatenate((labels_balanced_onehot, labels_augmented), axis=0)

# Shuffle the concatenated dataset
augmented_images_conc, augmented_labels_conc = shuffle(augmented_images_conc, augmented_labels_conc, random_state=seed)

# Needed for next block
images_augmented = augmented_images_conc
labels_augmented = augmented_labels_conc

# %%
X = images_augmented
y = labels_augmented
# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=.10, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=.15, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (5477, 96, 96, 3), y_train shape: (5477, 2)
# X_val shape: (967, 96, 96, 3), y_val shape: (967, 2)
# X_test shape: (716, 96, 96, 3), y_test shape: (716, 2)

# %%
# We apply image augmentation before training
preprocessing = tf.keras.Sequential([
          tfkl.RandomBrightness(0.2, (0,1)),
          tfkl.RandomRotation(0.2),
          tfkl.RandomFlip("horizontal"),
      ], name='preprocessing_efficientNet')
    
X_train = preprocessing(X_train)
X_val = preprocessing(X_val)
X_test = preprocessing(X_test)

# %% [markdown]
# Efficient net transfer learning

# %%
#EfficientNetV2S
efficientnet = tfk.applications.EfficientNetV2S(
    include_top=False,
    weights="imagenet",
    pooling='avg',
    classes=2,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 [==============================] - 1s 0us/step

# %%
from tensorflow.keras.regularizers import l2

def build_efficientnet():
# Image augmentation
    preprocessing = tf.keras.Sequential([
          tfkl.RandomBrightness(0.2, (0,1)),
          tfkl.RandomRotation(0.2),
          tfkl.RandomFlip("horizontal"),
      ], name='preprocessing_efficientNet')

# Use the supernet as feature extractor, i.e. freeze all its weigths
    efficientnet.trainable = False

# Create an input layer with shape (96, 96, 3)
    inputs = tfk.Input(shape=(96, 96, 3))

# Connect MobileNetV2 to the input
    x = efficientnet(inputs)

#Hyperparameters obtained using the tuner library
# Dense layer with regularizer between mobile net and batch
  #x = tfkl.Dense(units=hp.Int("units", min_value=32, max_value=512, step=32),
                 #kernel_regularizer=l2(0.01))(x)
    x = tfkl.Dense(1280)(x)
#x = tfkl.Dense(1280, activation='relu')(x)

# Add Batch Normalization
    x = tfkl.BatchNormalization(epsilon=1e-06, momentum=0.9, weights=None)(x)

# Dense layer between batch and dropout with regularizer
    x = tfkl.Dense(640)(x)
#x = tfkl.Dense(640, activation='relu')(x)

# Add a Dropout layer with 0.4
    x = tfkl.Dropout(0.5)(x)

# Add a Dense layer with 2 units and softmax activation as the classifier
    outputs = tfkl.Dense(2, activation='softmax')(x)

# Create a Model connecting input and output
    tl2_model = tfk.Model(inputs=inputs, outputs=outputs, name='model_efficientnet')

# Compile the model with Categorical Cross-Entropy loss and Adam optimizer

    tl2_model.summary()
    return tl2_model

# %%
tl2_model = build_efficientnet()
tl2_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])
# Out:
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-s (Function  (None, 1280)              20331360
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  dropout (Dropout)           (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 22797282 (86.96 MB)
# Trainable params: 2463362 (9.40 MB)
# Non-trainable params: 20333920 (77.57 MB)
# _________________________________________________________________

# %%
# Train the model
history = tl2_model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    #sample_weight = weights,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)]
).history
# Out:
# Epoch 1/200
# 343/343 [==============================] - 40s 37ms/step - loss: 1.6660 - accuracy: 0.6613 - val_loss: 0.6200 - val_accuracy: 0.7415 - lr: 0.0010
# Epoch 2/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.6533 - accuracy: 0.7241 - val_loss: 0.5559 - val_accuracy: 0.7446 - lr: 0.0010
# Epoch 3/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.5789 - accuracy: 0.7406 - val_loss: 0.6477 - val_accuracy: 0.7508 - lr: 0.0010
# Epoch 4/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.5646 - accuracy: 0.7502 - val_loss: 0.5886 - val_accuracy: 0.7456 - lr: 0.0010
# Epoch 5/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.5978 - accuracy: 0.7438 - val_loss: 0.6269 - val_accuracy: 0.7291 - lr: 0.0010
# Epoch 6/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.5944 - accuracy: 0.7422 - val_loss: 0.6047 - val_accuracy: 0.7559 - lr: 0.0010
# Epoch 7/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.5841 - accuracy: 0.7521 - val_loss: 0.5573 - val_accuracy: 0.7725 - lr: 0.0010
# Epoch 8/200
# 343/343 [==============================] - 8s 23ms/step - loss: 0.4702 - accuracy: 0.7939 - val_loss: 0.4578 - val_accuracy: 0.7942 - lr: 1.0000e-04
# Epoch 9/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4531 - accuracy: 0.7981 - val_loss: 0.4380 - val_accuracy: 0.7973 - lr: 1.0000e-04
# Epoch 10/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4410 - accuracy: 0.7981 - val_loss: 0.4538 - val_accuracy: 0.8004 - lr: 1.0000e-04
# Epoch 11/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4389 - accuracy: 0.8108 - val_loss: 0.4472 - val_accuracy: 0.8056 - lr: 1.0000e-04
# Epoch 12/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4346 - accuracy: 0.8077 - val_loss: 0.4582 - val_accuracy: 0.7994 - lr: 1.0000e-04
# Epoch 13/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4376 - accuracy: 0.8112 - val_loss: 0.4437 - val_accuracy: 0.8066 - lr: 1.0000e-04
# Epoch 14/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4258 - accuracy: 0.8101 - val_loss: 0.4490 - val_accuracy: 0.8035 - lr: 1.0000e-04
# Epoch 15/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4197 - accuracy: 0.8165 - val_loss: 0.4366 - val_accuracy: 0.8056 - lr: 1.0000e-05
# Epoch 16/200
# 343/343 [==============================] - 8s 23ms/step - loss: 0.4172 - accuracy: 0.8136 - val_loss: 0.4335 - val_accuracy: 0.8077 - lr: 1.0000e-05
# Epoch 17/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4225 - accuracy: 0.8116 - val_loss: 0.4344 - val_accuracy: 0.8035 - lr: 1.0000e-05
# Epoch 18/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4160 - accuracy: 0.8152 - val_loss: 0.4338 - val_accuracy: 0.8128 - lr: 1.0000e-05
# Epoch 19/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4198 - accuracy: 0.8169 - val_loss: 0.4429 - val_accuracy: 0.8046 - lr: 1.0000e-05
# Epoch 20/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4168 - accuracy: 0.8238 - val_loss: 0.4344 - val_accuracy: 0.8056 - lr: 1.0000e-05
# Epoch 21/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4141 - accuracy: 0.8183 - val_loss: 0.4351 - val_accuracy: 0.8139 - lr: 1.0000e-05
# Epoch 22/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4112 - accuracy: 0.8198 - val_loss: 0.4420 - val_accuracy: 0.8035 - lr: 1.0000e-06
# Epoch 23/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4125 - accuracy: 0.8202 - val_loss: 0.4342 - val_accuracy: 0.8108 - lr: 1.0000e-06
# Epoch 24/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4177 - accuracy: 0.8194 - val_loss: 0.4343 - val_accuracy: 0.8118 - lr: 1.0000e-06
# Epoch 25/200
# 343/343 [==============================] - 8s 23ms/step - loss: 0.4162 - accuracy: 0.8214 - val_loss: 0.4324 - val_accuracy: 0.8149 - lr: 1.0000e-06
# Epoch 26/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4161 - accuracy: 0.8191 - val_loss: 0.4335 - val_accuracy: 0.8087 - lr: 1.0000e-06
# Epoch 27/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4181 - accuracy: 0.8229 - val_loss: 0.4318 - val_accuracy: 0.8149 - lr: 1.0000e-06
# Epoch 28/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4094 - accuracy: 0.8273 - val_loss: 0.4412 - val_accuracy: 0.8066 - lr: 1.0000e-06
# Epoch 29/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4079 - accuracy: 0.8220 - val_loss: 0.4345 - val_accuracy: 0.8097 - lr: 1.0000e-06
# Epoch 30/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4171 - accuracy: 0.8200 - val_loss: 0.4330 - val_accuracy: 0.8108 - lr: 1.0000e-06
# Epoch 31/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4190 - accuracy: 0.8160 - val_loss: 0.4330 - val_accuracy: 0.8108 - lr: 1.0000e-06
# Epoch 32/200
# 343/343 [==============================] - 7s 22ms/step - loss: 0.4117 - accuracy: 0.8236 - val_loss: 0.4328 - val_accuracy: 0.8118 - lr: 1.0000e-06
# Epoch 33/200
# 343/343 [==============================] - 8s 22ms/step - loss: 0.4150 - accuracy: 0.8181 - val_loss: 0.4327 - val_accuracy: 0.8118 - lr: 1.0000e-07
# Epoch 34/200
# 343/343 [==============================] - 7s 21ms/step - loss: 0.4141 - accuracy: 0.8264 - val_loss: 0.4317 - val_accuracy: 0.8097 - lr: 1.0000e-07
# Epoch 35/200
# 343/343 [==============================] - 8s 23ms/step - loss: 0.4135 - accuracy: 0.8192 - val_loss: 0.4321 - val_accuracy: 0.8108 - lr: 1.0000e-07

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='EfficientNet V2 S Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='EfficientNet V2 S Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
tl2_model.save('/kaggle/working/TransferLearningModelEfficientNetS')

# %%
# Predict labels for the entire test set (augmented)
X_test = preprocess_input(X_test*255)
predictions = tl2_model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(('healthy','unhealthy')), yticklabels=list(('healthy','unhealthy')), cmap='Blues', annot=True)
plt.title('Predictions of the augmented test set')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (716, 2)
# Accuracy: 0.7947
# Precision: 0.7947
# Recall: 0.7947
# F1: 0.7947

# %%
def cutmix(images, labels, beta=1.0):
    """
    Apply CutMix data augmentation to a dataset.

    Args:
    images (numpy.ndarray): An array of images with shape (num_samples, height, width, channels).
    labels (numpy.ndarray): An array of labels with shape (num_samples, num_classes).
    beta (float): CutMix hyperparameter (default is 1.0).

    Returns:
    mixed_images (numpy.ndarray): Mixed images.
    mixed_labels (numpy.ndarray): Mixed labels.
    """
    num_samples, height, width, channels = images.shape

    # Randomly choose another sample to cut and mix with
    indices = np.arange(num_samples)
    np.random.shuffle(indices)
    mixed_images = images.copy()
    mixed_labels = labels.copy()

    for i in range(num_samples):
        j = indices[i]
        lam = np.random.beta(beta, beta)
        x, y, h, w = get_random_bbox(width, height, lam)
        mixed_images[i, y:y+h, x:x+w, :] = images[j, y:y+h, x:x+w, :]
        lam = 1 - (w * h / (width * height))
        mixed_labels[i] = lam * labels[i] + (1 - lam) * labels[j]

    return mixed_images, mixed_labels

def get_random_bbox(width, height, lam):
    r_x = np.random.randint(width)
    r_y = np.random.randint(height)
    r_w = int(width * np.sqrt(1 - lam))
    r_h = int(height * np.sqrt(1 - lam))
    x1 = np.clip(r_x - r_w // 2, 0, width)
    y1 = np.clip(r_y - r_h // 2, 0, height)
    x2 = np.clip(r_x + r_w // 2, 0, width)
    y2 = np.clip(r_y + r_h // 2, 0, height)
    return x1, y1, x2 - x1, y2 - y1

# Example usage:
# Assuming 'images' is your image dataset and 'labels' are the corresponding labels
images_augmented, labels_augmented_onehot = cutmix(images_balanced, labels_balanced_onehot, beta=1.0)

# %%
# Needed for next layer
labels_augmented = labels_augmented_onehot
images_augmented = images_augmented

# %%
from sklearn.utils import shuffle
# Concatenate the original dataset with the mixup dataset
augmented_images_conc = np.concatenate((images_balanced, images_augmented), axis=0)
augmented_labels_conc = np.concatenate((labels_balanced_onehot, labels_augmented), axis=0)

# Shuffle the concatenated dataset
augmented_images_conc, augmented_labels_conc = shuffle(augmented_images_conc, augmented_labels_conc, random_state=seed)

#to make sure the next blocks work
images_augmented = augmented_images_conc
labels_augmented = augmented_labels_conc

# %%
if labels_augmented.ndim == 1:
  print("eseguendo onehot\n")

  # Assuming 'labels_balanced' is a NumPy array containing your categorical labels
  labels_onehot = labels_augmented  # Replace with your actual labels

  # Get the unique categories in your label array
  unique_categories = np.unique(labels_onehot)

  # Initialize an empty array for one-hot encoded labels
  one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

  # Create one-hot encoded labels
  for i, category in enumerate(unique_categories):
     one_hot_labels[:, i] = (labels_onehot == category).astype(int)

  # Now, 'one_hot_labels' contains the one-hot encoded labels
  labels_augmented_onehot = one_hot_labels

else:
  print("one-hot già eseguito\n")

  labels_augmented_onehot = labels_augmented
# Out:
# one-hot già eseguito

# %%
X = images_augmented
y = labels_augmented_onehot
# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=.10, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=.15, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (5477, 96, 96, 3), y_train shape: (5477, 2)
# X_val shape: (967, 96, 96, 3), y_val shape: (967, 2)
# X_test shape: (716, 96, 96, 3), y_test shape: (716, 2)

# %%
# Re-load the model after transfer learning
ft2_model = tl2_model
del tl2_model

#ft2_model = build_efficientnet()
ft2_model.summary()

# Set all MobileNetV2 layers as trainable
ft2_model.get_layer('efficientnetv2-s').trainable = True
# Out:
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-s (Function  (None, 1280)              20331360
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  dropout (Dropout)           (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 22797282 (86.96 MB)
# Trainable params: 2463362 (9.40 MB)
# Non-trainable params: 20333920 (77.57 MB)
# _________________________________________________________________

# %%
# Freeze first N layers, e.g., until the 133rd one
#meno layer??
#N = 71
N = 265
for i, layer in enumerate(ft2_model.get_layer('efficientnetv2-s').layers[:N]):
  layer.trainable=False
ft2_model.summary()

ft2_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-5), metrics=['accuracy'])
# Out:
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-s (Function  (None, 1280)              20331360
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  dropout (Dropout)           (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 22797282 (86.96 MB)
# Trainable params: 17984954 (68.61 MB)
# Non-trainable params: 4812328 (18.36 MB)
# _________________________________________________________________

# %%
# Fine-tune the model
history = ft2_model.fit(
    x = preprocess_input(X_train*255), 
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val), 
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True),
                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)]
).history
# Out:
# Epoch 1/200
# 343/343 [==============================] - 74s 67ms/step - loss: 0.6998 - accuracy: 0.6615 - val_loss: 0.6090 - val_accuracy: 0.6701 - lr: 1.0000e-05
# Epoch 2/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.5681 - accuracy: 0.7141 - val_loss: 0.5717 - val_accuracy: 0.6877 - lr: 1.0000e-05
# Epoch 3/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.5325 - accuracy: 0.7464 - val_loss: 0.5491 - val_accuracy: 0.7229 - lr: 1.0000e-05
# Epoch 4/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.4940 - accuracy: 0.7805 - val_loss: 0.5211 - val_accuracy: 0.7570 - lr: 1.0000e-05
# Epoch 5/200
# 343/343 [==============================] - 19s 56ms/step - loss: 0.4782 - accuracy: 0.7946 - val_loss: 0.5019 - val_accuracy: 0.7622 - lr: 1.0000e-05
# Epoch 6/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.4472 - accuracy: 0.8161 - val_loss: 0.4879 - val_accuracy: 0.7870 - lr: 1.0000e-05
# Epoch 7/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.4173 - accuracy: 0.8328 - val_loss: 0.4869 - val_accuracy: 0.7911 - lr: 1.0000e-05
# Epoch 8/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.4005 - accuracy: 0.8402 - val_loss: 0.4916 - val_accuracy: 0.7890 - lr: 1.0000e-05
# Epoch 9/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.3775 - accuracy: 0.8534 - val_loss: 0.4793 - val_accuracy: 0.7963 - lr: 1.0000e-05
# Epoch 10/200
# 343/343 [==============================] - 19s 56ms/step - loss: 0.3591 - accuracy: 0.8711 - val_loss: 0.4747 - val_accuracy: 0.8004 - lr: 1.0000e-05
# Epoch 11/200
# 343/343 [==============================] - 19s 56ms/step - loss: 0.3418 - accuracy: 0.8797 - val_loss: 0.4687 - val_accuracy: 0.8159 - lr: 1.0000e-05
# Epoch 12/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.3375 - accuracy: 0.8793 - val_loss: 0.4494 - val_accuracy: 0.8190 - lr: 1.0000e-05
# Epoch 13/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.3175 - accuracy: 0.8928 - val_loss: 0.4637 - val_accuracy: 0.8004 - lr: 1.0000e-05
# Epoch 14/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.3127 - accuracy: 0.9005 - val_loss: 0.4511 - val_accuracy: 0.8170 - lr: 1.0000e-05
# Epoch 15/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.2984 - accuracy: 0.9056 - val_loss: 0.4454 - val_accuracy: 0.8252 - lr: 1.0000e-05
# Epoch 16/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.2919 - accuracy: 0.9072 - val_loss: 0.4441 - val_accuracy: 0.8211 - lr: 1.0000e-05
# Epoch 17/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.2830 - accuracy: 0.9160 - val_loss: 0.4513 - val_accuracy: 0.8335 - lr: 1.0000e-05
# Epoch 18/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.2627 - accuracy: 0.9275 - val_loss: 0.4377 - val_accuracy: 0.8232 - lr: 1.0000e-05
# Epoch 19/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2687 - accuracy: 0.9169 - val_loss: 0.4320 - val_accuracy: 0.8304 - lr: 1.0000e-05
# Epoch 20/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2657 - accuracy: 0.9233 - val_loss: 0.4417 - val_accuracy: 0.8273 - lr: 1.0000e-05
# Epoch 21/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2606 - accuracy: 0.9246 - val_loss: 0.4549 - val_accuracy: 0.8273 - lr: 1.0000e-05
# Epoch 22/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.2482 - accuracy: 0.9397 - val_loss: 0.4358 - val_accuracy: 0.8283 - lr: 1.0000e-05
# Epoch 23/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.2478 - accuracy: 0.9319 - val_loss: 0.4236 - val_accuracy: 0.8325 - lr: 1.0000e-05
# Epoch 24/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.2459 - accuracy: 0.9350 - val_loss: 0.4546 - val_accuracy: 0.8283 - lr: 1.0000e-05
# Epoch 25/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.2438 - accuracy: 0.9297 - val_loss: 0.4167 - val_accuracy: 0.8376 - lr: 1.0000e-05
# Epoch 26/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2418 - accuracy: 0.9292 - val_loss: 0.4191 - val_accuracy: 0.8366 - lr: 1.0000e-05
# Epoch 27/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2385 - accuracy: 0.9328 - val_loss: 0.4247 - val_accuracy: 0.8376 - lr: 1.0000e-05
# Epoch 28/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.2374 - accuracy: 0.9341 - val_loss: 0.4087 - val_accuracy: 0.8594 - lr: 1.0000e-05
# Epoch 29/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2333 - accuracy: 0.9365 - val_loss: 0.4167 - val_accuracy: 0.8418 - lr: 1.0000e-05
# Epoch 30/200
# 343/343 [==============================] - 19s 56ms/step - loss: 0.2335 - accuracy: 0.9368 - val_loss: 0.4171 - val_accuracy: 0.8469 - lr: 1.0000e-05
# Epoch 31/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.2307 - accuracy: 0.9390 - val_loss: 0.4093 - val_accuracy: 0.8511 - lr: 1.0000e-05
# Epoch 32/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2183 - accuracy: 0.9432 - val_loss: 0.4082 - val_accuracy: 0.8438 - lr: 1.0000e-05
# Epoch 33/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2249 - accuracy: 0.9390 - val_loss: 0.4119 - val_accuracy: 0.8407 - lr: 1.0000e-05
# Epoch 34/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.2253 - accuracy: 0.9368 - val_loss: 0.3952 - val_accuracy: 0.8532 - lr: 1.0000e-05
# Epoch 35/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2286 - accuracy: 0.9363 - val_loss: 0.4011 - val_accuracy: 0.8583 - lr: 1.0000e-05
# Epoch 36/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2228 - accuracy: 0.9357 - val_loss: 0.4129 - val_accuracy: 0.8428 - lr: 1.0000e-05
# Epoch 37/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2134 - accuracy: 0.9460 - val_loss: 0.4099 - val_accuracy: 0.8511 - lr: 1.0000e-05
# Epoch 38/200
# 343/343 [==============================] - 19s 55ms/step - loss: 0.2191 - accuracy: 0.9372 - val_loss: 0.3965 - val_accuracy: 0.8635 - lr: 1.0000e-05
# Epoch 39/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2160 - accuracy: 0.9390 - val_loss: 0.3946 - val_accuracy: 0.8635 - lr: 1.0000e-05
# Epoch 40/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2086 - accuracy: 0.9436 - val_loss: 0.4028 - val_accuracy: 0.8666 - lr: 1.0000e-05
# Epoch 41/200
# 343/343 [==============================] - 18s 52ms/step - loss: 0.2122 - accuracy: 0.9412 - val_loss: 0.4132 - val_accuracy: 0.8469 - lr: 1.0000e-05
# Epoch 42/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.2120 - accuracy: 0.9436 - val_loss: 0.3980 - val_accuracy: 0.8645 - lr: 1.0000e-05
# Epoch 43/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2024 - accuracy: 0.9463 - val_loss: 0.4471 - val_accuracy: 0.8511 - lr: 1.0000e-05
# Epoch 44/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2018 - accuracy: 0.9467 - val_loss: 0.4013 - val_accuracy: 0.8573 - lr: 1.0000e-05
# Epoch 45/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2069 - accuracy: 0.9441 - val_loss: 0.3933 - val_accuracy: 0.8656 - lr: 1.0000e-06
# Epoch 46/200
# 343/343 [==============================] - 18s 52ms/step - loss: 0.2061 - accuracy: 0.9487 - val_loss: 0.3997 - val_accuracy: 0.8594 - lr: 1.0000e-06
# Epoch 47/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2017 - accuracy: 0.9472 - val_loss: 0.3886 - val_accuracy: 0.8687 - lr: 1.0000e-06
# Epoch 48/200
# 343/343 [==============================] - 18s 52ms/step - loss: 0.2009 - accuracy: 0.9496 - val_loss: 0.4004 - val_accuracy: 0.8656 - lr: 1.0000e-06
# Epoch 49/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2061 - accuracy: 0.9498 - val_loss: 0.3886 - val_accuracy: 0.8645 - lr: 1.0000e-06
# Epoch 50/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2057 - accuracy: 0.9507 - val_loss: 0.3960 - val_accuracy: 0.8604 - lr: 1.0000e-06
# Epoch 51/200
# 343/343 [==============================] - 18s 52ms/step - loss: 0.2051 - accuracy: 0.9452 - val_loss: 0.3896 - val_accuracy: 0.8614 - lr: 1.0000e-06
# Epoch 52/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2022 - accuracy: 0.9481 - val_loss: 0.3900 - val_accuracy: 0.8625 - lr: 1.0000e-06
# Epoch 53/200
# 343/343 [==============================] - 18s 52ms/step - loss: 0.2075 - accuracy: 0.9418 - val_loss: 0.3960 - val_accuracy: 0.8614 - lr: 1.0000e-07
# Epoch 54/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2066 - accuracy: 0.9441 - val_loss: 0.3938 - val_accuracy: 0.8656 - lr: 1.0000e-07
# Epoch 55/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2022 - accuracy: 0.9480 - val_loss: 0.3947 - val_accuracy: 0.8707 - lr: 1.0000e-07
# Epoch 56/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.1964 - accuracy: 0.9454 - val_loss: 0.4103 - val_accuracy: 0.8614 - lr: 1.0000e-07
# Epoch 57/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2044 - accuracy: 0.9419 - val_loss: 0.3818 - val_accuracy: 0.8666 - lr: 1.0000e-07
# Epoch 58/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2052 - accuracy: 0.9388 - val_loss: 0.4036 - val_accuracy: 0.8583 - lr: 1.0000e-07
# Epoch 59/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.1997 - accuracy: 0.9449 - val_loss: 0.4030 - val_accuracy: 0.8521 - lr: 1.0000e-07
# Epoch 60/200
# 343/343 [==============================] - 18s 52ms/step - loss: 0.2071 - accuracy: 0.9465 - val_loss: 0.3959 - val_accuracy: 0.8594 - lr: 1.0000e-07
# Epoch 61/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2070 - accuracy: 0.9408 - val_loss: 0.3942 - val_accuracy: 0.8666 - lr: 1.0000e-07
# Epoch 62/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2023 - accuracy: 0.9465 - val_loss: 0.3970 - val_accuracy: 0.8583 - lr: 1.0000e-07
# Epoch 63/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2007 - accuracy: 0.9472 - val_loss: 0.3989 - val_accuracy: 0.8625 - lr: 1.0000e-08
# Epoch 64/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.1979 - accuracy: 0.9463 - val_loss: 0.4093 - val_accuracy: 0.8594 - lr: 1.0000e-08
# Epoch 65/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.2075 - accuracy: 0.9450 - val_loss: 0.3921 - val_accuracy: 0.8573 - lr: 1.0000e-08
# Epoch 66/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.2004 - accuracy: 0.9430 - val_loss: 0.3952 - val_accuracy: 0.8656 - lr: 1.0000e-08
# Epoch 67/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2013 - accuracy: 0.9483 - val_loss: 0.3946 - val_accuracy: 0.8573 - lr: 1.0000e-08
# Epoch 68/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.2051 - accuracy: 0.9432 - val_loss: 0.4146 - val_accuracy: 0.8645 - lr: 1.0000e-09
# Epoch 69/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2017 - accuracy: 0.9485 - val_loss: 0.3837 - val_accuracy: 0.8687 - lr: 1.0000e-09
# Epoch 70/200
# 343/343 [==============================] - 18s 54ms/step - loss: 0.2086 - accuracy: 0.9429 - val_loss: 0.3844 - val_accuracy: 0.8687 - lr: 1.0000e-09
# Epoch 71/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2004 - accuracy: 0.9423 - val_loss: 0.3899 - val_accuracy: 0.8635 - lr: 1.0000e-09
# Epoch 72/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.1978 - accuracy: 0.9483 - val_loss: 0.3989 - val_accuracy: 0.8666 - lr: 1.0000e-09
# Epoch 73/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2119 - accuracy: 0.9354 - val_loss: 0.3894 - val_accuracy: 0.8625 - lr: 1.0000e-10
# Epoch 74/200
# 343/343 [==============================] - 18s 53ms/step - loss: 0.2009 - accuracy: 0.9454 - val_loss: 0.4376 - val_accuracy: 0.8407 - lr: 1.0000e-10
# Epoch 75/200
# 343/343 [==============================] - 19s 54ms/step - loss: 0.2006 - accuracy: 0.9489 - val_loss: 0.4029 - val_accuracy: 0.8666 - lr: 1.0000e-10

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='EfficientNet V2 S Fine Tuning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='EfficientNet V2 S Fine Tuning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the best model
ft2_model.save('/kaggle/working/FineTuningModelEfficientNetS')

# %%
# Predict labels for the entire test set (augmented)
X_test = preprocess_input(X_test*255)
predictions = ft2_model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(('healthy','unhealthy')), yticklabels=list(('healthy','unhealthy')), cmap='Blues', annot=True)
plt.title('Predictions of the augmented test set')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (716, 2)
# Accuracy: 0.8617
# Precision: 0.8637
# Recall: 0.8613
# F1: 0.8614
