# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/challenge/dataset_refined.npz

# %%
# Fix randomness and hide warnings
seed = 13

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# Import tensorflow
import tensorflow as tf

from tensorflow import keras as tfk
from keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)

# Import other libraries
import cv2
from keras.applications.efficientnet_v2 import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import seaborn as sns
from PIL import Image
import pandas as pd
# Out:
# 2.13.0

# %%
data = np.load('/kaggle/input/challenge/dataset_refined.npz', allow_pickle=True)

images = data['arr_0']
labels = data['arr_1']
labels = np.array(labels)
images = np.array(images)

# %%
from imblearn.over_sampling import SMOTE
# Solve class imbalance with SMOTE
# Initialize the SMOTE object
smote = SMOTE(sampling_strategy=0.75, random_state=seed)

# Flatten the images
images_flat = images.reshape(images.shape[0], -1)  # Reshape to (num_samples, num_features)

# Now you can use SMOTE on 'images_flat'
images_smote, labels_smote = smote.fit_resample(images_flat, labels)

# Now, 'images_smote' and 'labels_smote' contain the oversampled dataset
# Reshape the images
original_shape = (96, 96, 3)

images_original_shape = images_smote.reshape(-1, *original_shape)

# %%
# Needed for next step
images_balanced = images_original_shape
labels_balanced = labels_smote

# %%
#Show the data
# Number of images to display
size = labels_balanced.size
num_img = 10
# Create a random index to display every time a different set of images
random_index = np.random.rand()
random_index = int(random_index*(size-num_img))

# Create subplots for displaying items
fig, axes = plt.subplots(2, num_img//2, figsize=(20, 9))
for i in range(random_index, random_index + num_img):
    title = 'true label: ' + str(labels_balanced[i]) + ' index: ' + str(i)
    ax = axes[i%2, i%num_img//2]
    ax.set_title(title)
    ax.imshow(np.clip(images_balanced[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
print('Dataset campionato: ' + str(labels_balanced.size))
print('Dataset originale: ' + str(labels.size))
counts, unique = np.unique(labels_balanced, return_counts = True)
for i in range(counts.size):
  print(counts[i] + ': ' + str(unique[i]))
# Out:
# Dataset campionato: 5355
# Dataset originale: 4850
# healthy: 3060
# unhealthy: 2295

# %% [markdown]
# augmentation

# %%
# One-Hot Encoding
# Assuming 'labels_balanced' is a NumPy array containing your categorical labels
labels_onehot = labels_balanced  # Replace with your actual labels

# Get the unique categories in your label array
unique_categories = np.unique(labels_onehot)

# Initialize an empty array for one-hot encoded labels
one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

# Create one-hot encoded labels
for i, category in enumerate(unique_categories):
    one_hot_labels[:, i] = (labels_onehot == category).astype(int)

# Now, 'one_hot_labels' contains the one-hot encoded labels
labels_balanced_onehot = one_hot_labels

# %%
# Define a function to perform MixUp on the dataset
def mixup_data(X, y, alpha=0.2):
    mixed_X = []
    mixed_y = []

    for i in range(len(X)):
        # Randomly select another sample to mix with
        j = np.random.randint(len(X))

        # Randomly select a mixing ratio from a beta distribution
        beta = np.random.beta(alpha, alpha)

        mixed_X.append((X[i] * beta) + (X[j] * (1 - beta)))
        mixed_y.append((y[i] * beta) + (y[j] * (1 - beta)))

    mixed_X = np.array(mixed_X)
    mixed_y = np.array(mixed_y)

    return mixed_X, mixed_y

# Perform MixUp on your training data
images_augmented, labels_augmented_onehot = mixup_data(images_balanced, labels_balanced_onehot, alpha=0.2)

# %%
# Needed for next block
labels_augmented = labels_augmented_onehot
images_augmented = images_augmented

# %%
from sklearn.utils import shuffle
# Concatenate the original dataset with the mixup dataset
augmented_images_conc = np.concatenate((images_balanced, images_augmented), axis=0)
augmented_labels_conc = np.concatenate((labels_balanced_onehot, labels_augmented), axis=0)

# Shuffle the concatenated dataset
augmented_images_conc, augmented_labels_conc = shuffle(augmented_images_conc, augmented_labels_conc, random_state=seed)

# To make sure the next blocks work
images_augmented = augmented_images_conc
labels_augmented = augmented_labels_conc

# %%
if labels_augmented.ndim == 1:
  print("eseguendo onehot\n")

  # Assuming 'labels_balanced' is a NumPy array containing your categorical labels
  labels_onehot = labels_augmented  # Replace with your actual labels

  # Get the unique categories in your label array
  unique_categories = np.unique(labels_onehot)

  # Initialize an empty array for one-hot encoded labels
  one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

  # Create one-hot encoded labels
  for i, category in enumerate(unique_categories):
     one_hot_labels[:, i] = (labels_onehot == category).astype(int)

  # Now, 'one_hot_labels' contains the one-hot encoded labels
  labels_augmented_onehot = one_hot_labels

else:
  print("one-hot già eseguito\n")

  labels_augmented_onehot = labels_augmented
# Out:
# one-hot già eseguito

# %%
X = images_augmented
y = labels_augmented_onehot
# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=.10, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=.10, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (8675, 96, 96, 3), y_train shape: (8675, 2)
# X_val shape: (964, 96, 96, 3), y_val shape: (964, 2)
# X_test shape: (1071, 96, 96, 3), y_test shape: (1071, 2)

# %%
# We apply Image Augmentation before
preprocessing = tf.keras.Sequential([
          tfkl.RandomBrightness(0.2, (0,1)),
          tfkl.RandomRotation(0.2),
          tfkl.RandomFlip("horizontal"),
      ], name='preprocessing_efficientNet')
    
X_train = preprocessing(X_train)
X_val = preprocessing(X_val)
X_test = preprocessing(X_test)

# %% [markdown]
# Efficient net transfer learning

# %%
#EfficientNetV2S
efficientnet = tfk.applications.EfficientNetV2L(
    include_top=False,
    weights="imagenet",
    pooling='avg',
    classes=2,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 [==============================] - 19s 0us/step

# %%
from tensorflow.keras.regularizers import l2

def build_efficientnet():
# Image augmentation
    preprocessing = tf.keras.Sequential([
          tfkl.RandomBrightness(0.2, (0,1)),
          tfkl.RandomRotation(0.2),
          tfkl.RandomFlip("horizontal"),
      ], name='preprocessing_efficientNet')

# Use the supernet as feature extractor, i.e. freeze all its weigths
    efficientnet.trainable = False

# Create an input layer with shape (96, 96, 3)
    inputs = tfk.Input(shape=(96, 96, 3))

# Connect MobileNetV2 to the input
    x = efficientnet(inputs)

#Hyperparameters obtained using the tuner library
# Dense layer with regularizer between mobile net and batch
  #x = tfkl.Dense(units=hp.Int("units", min_value=32, max_value=512, step=32),
                 #kernel_regularizer=l2(0.01))(x)
    x = tfkl.Dense(1280, activation='relu')(x)
#x = tfkl.Dense(1280, activation='relu')(x)

# Add Batch Normalization
    x = tfkl.BatchNormalization(epsilon=1e-06, momentum=0.9, weights=None)(x)

# Dense layer between batch and dropout with regularizer
    x = tfkl.Dense(640, activation='relu')(x)
#x = tfkl.Dense(640, activation='relu')(x)

# Add a Dropout layer with 0.4
    x = tfkl.Dropout(0.5)(x)

# Add a Dense layer with 2 units and softmax activation as the classifier
    outputs = tfkl.Dense(2, activation='softmax')(x)

# Create a Model connecting input and output
    tl2_model = tfk.Model(inputs=inputs, outputs=outputs, name='model_efficientnet')

    tl2_model.summary()
    return tl2_model

# %%
tl2_model = build_efficientnet()
# Compile the model with Categorical Cross-Entropy loss and Adam optimizer
tl2_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])
# Out:
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-l (Function  (None, 1280)              117746848
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  dropout (Dropout)           (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 120212770 (458.58 MB)
# Trainable params: 2463362 (9.40 MB)
# Non-trainable params: 117749408 (449.18 MB)
# _________________________________________________________________

# %%
# Train the model
history = tl2_model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    #sample_weight = weights,
    batch_size = 30,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)]
).history
# Out:
# Epoch 1/200
# 290/290 [==============================] - 64s 103ms/step - loss: 1.0238 - accuracy: 0.6797 - val_loss: 0.5401 - val_accuracy: 0.7562 - lr: 0.0010
# Epoch 2/200
# 290/290 [==============================] - 21s 72ms/step - loss: 0.5827 - accuracy: 0.7338 - val_loss: 0.4528 - val_accuracy: 0.7863 - lr: 0.0010
# Epoch 3/200
# 290/290 [==============================] - 20s 69ms/step - loss: 0.5016 - accuracy: 0.7656 - val_loss: 0.4500 - val_accuracy: 0.7822 - lr: 0.0010
# Epoch 4/200
# 290/290 [==============================] - 21s 73ms/step - loss: 0.4913 - accuracy: 0.7759 - val_loss: 0.4457 - val_accuracy: 0.8008 - lr: 0.0010
# Epoch 5/200
# 290/290 [==============================] - 21s 72ms/step - loss: 0.4739 - accuracy: 0.7872 - val_loss: 0.4452 - val_accuracy: 0.8081 - lr: 0.0010
# Epoch 6/200
# 290/290 [==============================] - 20s 69ms/step - loss: 0.4661 - accuracy: 0.7922 - val_loss: 0.4611 - val_accuracy: 0.7853 - lr: 0.0010
# Epoch 7/200
# 290/290 [==============================] - 20s 70ms/step - loss: 0.4667 - accuracy: 0.7881 - val_loss: 0.4609 - val_accuracy: 0.7707 - lr: 0.0010
# Epoch 8/200
# 290/290 [==============================] - 21s 72ms/step - loss: 0.4482 - accuracy: 0.8007 - val_loss: 0.4270 - val_accuracy: 0.8050 - lr: 0.0010
# Epoch 9/200
# 290/290 [==============================] - 21s 72ms/step - loss: 0.4389 - accuracy: 0.8095 - val_loss: 0.4277 - val_accuracy: 0.8143 - lr: 0.0010
# Epoch 10/200
# 290/290 [==============================] - 21s 72ms/step - loss: 0.4335 - accuracy: 0.8061 - val_loss: 0.4200 - val_accuracy: 0.8216 - lr: 0.0010
# Epoch 11/200
# 290/290 [==============================] - 21s 71ms/step - loss: 0.4198 - accuracy: 0.8184 - val_loss: 0.4273 - val_accuracy: 0.8195 - lr: 0.0010
# Epoch 12/200
# 290/290 [==============================] - 21s 71ms/step - loss: 0.4155 - accuracy: 0.8191 - val_loss: 0.4434 - val_accuracy: 0.8216 - lr: 0.0010
# Epoch 13/200
# 290/290 [==============================] - 21s 71ms/step - loss: 0.4142 - accuracy: 0.8204 - val_loss: 0.4216 - val_accuracy: 0.8050 - lr: 0.0010
# Epoch 14/200
# 290/290 [==============================] - 20s 71ms/step - loss: 0.4089 - accuracy: 0.8227 - val_loss: 0.4132 - val_accuracy: 0.8164 - lr: 0.0010
# Epoch 15/200
# 290/290 [==============================] - 20s 71ms/step - loss: 0.3989 - accuracy: 0.8273 - val_loss: 0.4535 - val_accuracy: 0.8029 - lr: 0.0010
# Epoch 16/200
# 290/290 [==============================] - 21s 73ms/step - loss: 0.3931 - accuracy: 0.8319 - val_loss: 0.4106 - val_accuracy: 0.8174 - lr: 0.0010
# Epoch 17/200
# 290/290 [==============================] - 21s 73ms/step - loss: 0.3947 - accuracy: 0.8350 - val_loss: 0.4129 - val_accuracy: 0.8205 - lr: 0.0010
# Epoch 18/200
# 290/290 [==============================] - 21s 72ms/step - loss: 0.3777 - accuracy: 0.8420 - val_loss: 0.4824 - val_accuracy: 0.8081 - lr: 0.0010
# Epoch 19/200
# 290/290 [==============================] - 21s 72ms/step - loss: 0.3817 - accuracy: 0.8355 - val_loss: 0.4375 - val_accuracy: 0.8174 - lr: 0.0010
# Epoch 20/200
# 290/290 [==============================] - 22s 75ms/step - loss: 0.3748 - accuracy: 0.8420 - val_loss: 0.4209 - val_accuracy: 0.8081 - lr: 0.0010

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='EfficientNet V2 L Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='EfficientNet V2 L Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
tl2_model.save('/kaggle/working/TransferLearningModelEfficientNetL')

# %%
# Predict labels for the entire test set (augmented)
X_test = preprocess_input(X_test*255)
predictions = tl2_model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(('healthy','unhealthy')), yticklabels=list(('healthy','unhealthy')), cmap='Blues', annot=True)
plt.title('Predictions of the augmented test set')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (1071, 2)
# Accuracy: 0.8067
# Precision: 0.8036
# Recall: 0.8083
# F1: 0.8047

# %%
def cutmix(images, labels, beta=1.0):
    """
    Apply CutMix data augmentation to a dataset.

    Args:
    images (numpy.ndarray): An array of images with shape (num_samples, height, width, channels).
    labels (numpy.ndarray): An array of labels with shape (num_samples, num_classes).
    beta (float): CutMix hyperparameter (default is 1.0).

    Returns:
    mixed_images (numpy.ndarray): Mixed images.
    mixed_labels (numpy.ndarray): Mixed labels.
    """
    num_samples, height, width, channels = images.shape

    # Randomly choose another sample to cut and mix with
    indices = np.arange(num_samples)
    np.random.shuffle(indices)
    mixed_images = images.copy()
    mixed_labels = labels.copy()

    for i in range(num_samples):
        j = indices[i]
        lam = np.random.beta(beta, beta)
        x, y, h, w = get_random_bbox(width, height, lam)
        mixed_images[i, y:y+h, x:x+w, :] = images[j, y:y+h, x:x+w, :]
        lam = 1 - (w * h / (width * height))
        mixed_labels[i] = lam * labels[i] + (1 - lam) * labels[j]

    return mixed_images, mixed_labels

def get_random_bbox(width, height, lam):
    r_x = np.random.randint(width)
    r_y = np.random.randint(height)
    r_w = int(width * np.sqrt(1 - lam))
    r_h = int(height * np.sqrt(1 - lam))
    x1 = np.clip(r_x - r_w // 2, 0, width)
    y1 = np.clip(r_y - r_h // 2, 0, height)
    x2 = np.clip(r_x + r_w // 2, 0, width)
    y2 = np.clip(r_y + r_h // 2, 0, height)
    return x1, y1, x2 - x1, y2 - y1

# Example usage:
# Assuming 'images' is your image dataset and 'labels' are the corresponding labels
images_augmented, labels_augmented_onehot = cutmix(images_balanced, labels_balanced_onehot, beta=1.0)

# %%
#PREPARE FOR NEXT LAYER
labels_augmented = labels_augmented_onehot
images_augmented = images_augmented

# %%
from sklearn.utils import shuffle
# Concatenate the original dataset with the mixup dataset
augmented_images_conc = np.concatenate((images_balanced, images_augmented), axis=0)
augmented_labels_conc = np.concatenate((labels_balanced_onehot, labels_augmented), axis=0)

# Shuffle the concatenated dataset
augmented_images_conc, augmented_labels_conc = shuffle(augmented_images_conc, augmented_labels_conc, random_state=seed)

#to make sure the next blocks work
images_augmented = augmented_images_conc
labels_augmented = augmented_labels_conc

# %%
if labels_augmented.ndim == 1:
  print("eseguendo onehot\n")

  # Assuming 'labels_balanced' is a NumPy array containing your categorical labels
  labels_onehot = labels_augmented  # Replace with your actual labels

  # Get the unique categories in your label array
  unique_categories = np.unique(labels_onehot)

  # Initialize an empty array for one-hot encoded labels
  one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

  # Create one-hot encoded labels
  for i, category in enumerate(unique_categories):
     one_hot_labels[:, i] = (labels_onehot == category).astype(int)

  # Now, 'one_hot_labels' contains the one-hot encoded labels

  labels_augmented_onehot = one_hot_labels


else:
  print("one-hot già eseguito\n")

  labels_augmented_onehot = labels_augmented
# Out:
# one-hot già eseguito

# %%
#remember to call the results of the previous section X (processed dataset) and y (one hot encoded labels)
X = images_augmented
y = labels_augmented_onehot
# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=.10, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=.10, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (8675, 96, 96, 3), y_train shape: (8675, 2)
# X_val shape: (964, 96, 96, 3), y_val shape: (964, 2)
# X_test shape: (1071, 96, 96, 3), y_test shape: (1071, 2)

# %%
# Image augmentation
preprocessing = tf.keras.Sequential([
          tfkl.RandomBrightness(0.2, (0,1)),
          tfkl.RandomRotation(0.2),
          tfkl.RandomFlip("horizontal"),
      ], name='preprocessing_efficientNet')
    
X_train = preprocessing(X_train)
X_val = preprocessing(X_val)
X_test = preprocessing(X_test)

# %%
# Re-load the model after transfer learning
ft2_model = tf.keras.models.load_model('/kaggle/working/TransferLearningModelEfficientNetL')
del tl2_model

#ft2_model = build_efficientnet()
ft2_model.summary()

# Set all MobileNetV2 layers as trainable
ft2_model.get_layer('efficientnetv2-l').trainable = True
for i, layer in enumerate(ft2_model.get_layer('efficientnetv2-l').layers):
   print(i, layer.name, layer.trainable)
# Out:
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-l (Function  (None, 1280)              117746848
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  dropout (Dropout)           (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 120212770 (458.58 MB)
# Trainable params: 2463362 (9.40 MB)
# Non-trainable params: 117749408 (449.18 MB)
# _________________________________________________________________
# 0 input_1 True
# 1 rescaling True
# 2 stem_conv True
# 3 stem_bn True
# 4 stem_activation True
# 5 block1a_project_conv True
# 6 block1a_project_bn True
# 7 block1a_project_activation True
# 8 block1a_add True
# 9 block1b_project_conv True
# 10 block1b_project_bn True
# 11 block1b_project_activation True
# 12 block1b_drop True
# 13 block1b_add True
# 14 block1c_project_conv True
# 15 block1c_project_bn True
# 16 block1c_project_activation True
# 17 block1c_drop True
# 18 block1c_add True
# 19 block1d_project_conv True
# 20 block1d_project_bn True
# 21 block1d_project_activation True
# 22 block1d_drop True
# 23 block1d_add True
# 24 block2a_expand_conv True
# 25 block2a_expand_bn True
# 26 block2a_expand_activation True
# 27 block2a_project_conv True
# 28 block2a_project_bn True
# 29 block2b_expand_conv True
# 30 block2b_expand_bn True
# 31 block2b_expand_activation True
# 32 block2b_project_conv True
# 33 block2b_project_bn True
# 34 block2b_drop True
# 35 block2b_add True
# 36 block2c_expand_conv True
# 37 block2c_expand_bn True
# 38 block2c_expand_activation True
# 39 block2c_project_conv True
# 40 block2c_project_bn True
# 41 block2c_drop True
# 42 block2c_add True
# 43 block2d_expand_conv True
# 44 block2d_expand_bn True
# 45 block2d_expand_activation True
# 46 block2d_project_conv True
# 47 block2d_project_bn True
# 48 block2d_drop True
# 49 block2d_add True
# 50 block2e_expand_conv True
# 51 block2e_expand_bn True
# 52 block2e_expand_activation True
# 53 block2e_project_conv True
# 54 block2e_project_bn True
# 55 block2e_drop True
# 56 block2e_add True
# 57 block2f_expand_conv True
# 58 block2f_expand_bn True
# 59 block2f_expand_activation True
# 60 block2f_project_conv True
# 61 block2f_project_bn True
# 62 block2f_drop True
# 63 block2f_add True
# 64 block2g_expand_conv True
# 65 block2g_expand_bn True
# 66 block2g_expand_activation True
# 67 block2g_project_conv True
# 68 block2g_project_bn True
# 69 block2g_drop True
# 70 block2g_add True
# 71 block3a_expand_conv True
# 72 block3a_expand_bn True
# 73 block3a_expand_activation True
# 74 block3a_project_conv True
# 75 block3a_project_bn True
# 76 block3b_expand_conv True
# 77 block3b_expand_bn True
# 78 block3b_expand_activation True
# 79 block3b_project_conv True
# 80 block3b_project_bn True
# 81 block3b_drop True
# 82 block3b_add True
# 83 block3c_expand_conv True
# 84 block3c_expand_bn True
# 85 block3c_expand_activation True
# 86 block3c_project_conv True
# 87 block3c_project_bn True
# 88 block3c_drop True
# 89 block3c_add True
# 90 block3d_expand_conv True
# 91 block3d_expand_bn True
# 92 block3d_expand_activation True
# 93 block3d_project_conv True
# 94 block3d_project_bn True
# 95 block3d_drop True
# 96 block3d_add True
# 97 block3e_expand_conv True
# 98 block3e_expand_bn True
# 99 block3e_expand_activation True
# 100 block3e_project_conv True
# 101 block3e_project_bn True
# 102 block3e_drop True
# 103 block3e_add True
# 104 block3f_expand_conv True
# 105 block3f_expand_bn True
# 106 block3f_expand_activation True
# 107 block3f_project_conv True
# 108 block3f_project_bn True
# 109 block3f_drop True
# 110 block3f_add True
# 111 block3g_expand_conv True
# 112 block3g_expand_bn True
# 113 block3g_expand_activation True
# 114 block3g_project_conv True
# 115 block3g_project_bn True
# 116 block3g_drop True
# 117 block3g_add True
# 118 block4a_expand_conv True
# 119 block4a_expand_bn True
# 120 block4a_expand_activation True
# 121 block4a_dwconv2 True
# 122 block4a_bn True
# 123 block4a_activation True
# 124 block4a_se_squeeze True
# 125 block4a_se_reshape True
# 126 block4a_se_reduce True
# 127 block4a_se_expand True
# 128 block4a_se_excite True
# 129 block4a_project_conv True
# 130 block4a_project_bn True
# 131 block4b_expand_conv True
# 132 block4b_expand_bn True
# 133 block4b_expand_activation True
# 134 block4b_dwconv2 True
# 135 block4b_bn True
# 136 block4b_activation True
# 137 block4b_se_squeeze True
# 138 block4b_se_reshape True
# 139 block4b_se_reduce True
# 140 block4b_se_expand True
# 141 block4b_se_excite True
# 142 block4b_project_conv True
# 143 block4b_project_bn True
# 144 block4b_drop True
# 145 block4b_add True
# 146 block4c_expand_conv True
# 147 block4c_expand_bn True
# 148 block4c_expand_activation True
# 149 block4c_dwconv2 True
# 150 block4c_bn True
# 151 block4c_activation True
# 152 block4c_se_squeeze True
# 153 block4c_se_reshape True
# 154 block4c_se_reduce True
# 155 block4c_se_expand True
# 156 block4c_se_excite True
# 157 block4c_project_conv True
# 158 block4c_project_bn True
# 159 block4c_drop True
# 160 block4c_add True
# 161 block4d_expand_conv True
# 162 block4d_expand_bn True
# 163 block4d_expand_activation True
# 164 block4d_dwconv2 True
# 165 block4d_bn True
# 166 block4d_activation True
# 167 block4d_se_squeeze True
# 168 block4d_se_reshape True
# 169 block4d_se_reduce True
# 170 block4d_se_expand True
# 171 block4d_se_excite True
# 172 block4d_project_conv True
# 173 block4d_project_bn True
# 174 block4d_drop True
# 175 block4d_add True
# 176 block4e_expand_conv True
# 177 block4e_expand_bn True
# 178 block4e_expand_activation True
# 179 block4e_dwconv2 True
# 180 block4e_bn True
# 181 block4e_activation True
# 182 block4e_se_squeeze True
# 183 block4e_se_reshape True
# 184 block4e_se_reduce True
# 185 block4e_se_expand True
# 186 block4e_se_excite True
# 187 block4e_project_conv True
# 188 block4e_project_bn True
# 189 block4e_drop True
# 190 block4e_add True
# 191 block4f_expand_conv True
# 192 block4f_expand_bn True
# 193 block4f_expand_activation True
# 194 block4f_dwconv2 True
# 195 block4f_bn True
# 196 block4f_activation True
# 197 block4f_se_squeeze True
# 198 block4f_se_reshape True
# 199 block4f_se_reduce True
# 200 block4f_se_expand True
# 201 block4f_se_excite True
# 202 block4f_project_conv True
# 203 block4f_project_bn True
# 204 block4f_drop True
# 205 block4f_add True
# 206 block4g_expand_conv True
# 207 block4g_expand_bn True
# 208 block4g_expand_activation True
# 209 block4g_dwconv2 True
# 210 block4g_bn True
# 211 block4g_activation True
# 212 block4g_se_squeeze True
# 213 block4g_se_reshape True
# 214 block4g_se_reduce True
# 215 block4g_se_expand True
# 216 block4g_se_excite True
# 217 block4g_project_conv True
# 218 block4g_project_bn True
# 219 block4g_drop True
# 220 block4g_add True
# 221 block4h_expand_conv True
# 222 block4h_expand_bn True
# 223 block4h_expand_activation True
# 224 block4h_dwconv2 True
# 225 block4h_bn True
# 226 block4h_activation True
# 227 block4h_se_squeeze True
# 228 block4h_se_reshape True
# 229 block4h_se_reduce True
# 230 block4h_se_expand True
# 231 block4h_se_excite True
# 232 block4h_project_conv True
# 233 block4h_project_bn True
# 234 block4h_drop True
# 235 block4h_add True
# 236 block4i_expand_conv True
# 237 block4i_expand_bn True
# 238 block4i_expand_activation True
# 239 block4i_dwconv2 True
# 240 block4i_bn True
# 241 block4i_activation True
# 242 block4i_se_squeeze True
# 243 block4i_se_reshape True
# 244 block4i_se_reduce True
# 245 block4i_se_expand True
# 246 block4i_se_excite True
# 247 block4i_project_conv True
# 248 block4i_project_bn True
# 249 block4i_drop True
# 250 block4i_add True
# 251 block4j_expand_conv True
# 252 block4j_expand_bn True
# 253 block4j_expand_activation True
# 254 block4j_dwconv2 True
# 255 block4j_bn True
# 256 block4j_activation True
# 257 block4j_se_squeeze True
# 258 block4j_se_reshape True
# 259 block4j_se_reduce True
# 260 block4j_se_expand True
# 261 block4j_se_excite True
# 262 block4j_project_conv True
# 263 block4j_project_bn True
# 264 block4j_drop True
# 265 block4j_add True
# 266 block5a_expand_conv True
# 267 block5a_expand_bn True
# 268 block5a_expand_activation True
# 269 block5a_dwconv2 True
# 270 block5a_bn True
# 271 block5a_activation True
# 272 block5a_se_squeeze True
# 273 block5a_se_reshape True
# 274 block5a_se_reduce True
# 275 block5a_se_expand True
# 276 block5a_se_excite True
# 277 block5a_project_conv True
# 278 block5a_project_bn True
# 279 block5b_expand_conv True
# 280 block5b_expand_bn True
# 281 block5b_expand_activation True
# 282 block5b_dwconv2 True
# 283 block5b_bn True
# 284 block5b_activation True
# 285 block5b_se_squeeze True
# 286 block5b_se_reshape True
# 287 block5b_se_reduce True
# 288 block5b_se_expand True
# 289 block5b_se_excite True
# 290 block5b_project_conv True
# 291 block5b_project_bn True
# 292 block5b_drop True
# 293 block5b_add True
# 294 block5c_expand_conv True
# 295 block5c_expand_bn True
# 296 block5c_expand_activation True
# 297 block5c_dwconv2 True
# 298 block5c_bn True
# 299 block5c_activation True
# 300 block5c_se_squeeze True
# 301 block5c_se_reshape True
# 302 block5c_se_reduce True
# 303 block5c_se_expand True
# 304 block5c_se_excite True
# 305 block5c_project_conv True
# 306 block5c_project_bn True
# 307 block5c_drop True
# 308 block5c_add True
# 309 block5d_expand_conv True
# 310 block5d_expand_bn True
# 311 block5d_expand_activation True
# 312 block5d_dwconv2 True
# 313 block5d_bn True
# 314 block5d_activation True
# 315 block5d_se_squeeze True
# 316 block5d_se_reshape True
# 317 block5d_se_reduce True
# 318 block5d_se_expand True
# 319 block5d_se_excite True
# 320 block5d_project_conv True
# 321 block5d_project_bn True
# 322 block5d_drop True
# 323 block5d_add True
# 324 block5e_expand_conv True
# 325 block5e_expand_bn True
# 326 block5e_expand_activation True
# 327 block5e_dwconv2 True
# 328 block5e_bn True
# 329 block5e_activation True
# 330 block5e_se_squeeze True
# 331 block5e_se_reshape True
# 332 block5e_se_reduce True
# 333 block5e_se_expand True
# 334 block5e_se_excite True
# 335 block5e_project_conv True
# 336 block5e_project_bn True
# 337 block5e_drop True
# 338 block5e_add True
# 339 block5f_expand_conv True
# 340 block5f_expand_bn True
# 341 block5f_expand_activation True
# 342 block5f_dwconv2 True
# 343 block5f_bn True
# 344 block5f_activation True
# 345 block5f_se_squeeze True
# 346 block5f_se_reshape True
# 347 block5f_se_reduce True
# 348 block5f_se_expand True
# 349 block5f_se_excite True
# 350 block5f_project_conv True
# 351 block5f_project_bn True
# 352 block5f_drop True
# 353 block5f_add True
# 354 block5g_expand_conv True
# 355 block5g_expand_bn True
# 356 block5g_expand_activation True
# 357 block5g_dwconv2 True
# 358 block5g_bn True
# 359 block5g_activation True
# 360 block5g_se_squeeze True
# 361 block5g_se_reshape True
# 362 block5g_se_reduce True
# 363 block5g_se_expand True
# 364 block5g_se_excite True
# 365 block5g_project_conv True
# 366 block5g_project_bn True
# 367 block5g_drop True
# 368 block5g_add True
# 369 block5h_expand_conv True
# 370 block5h_expand_bn True
# 371 block5h_expand_activation True
# 372 block5h_dwconv2 True
# 373 block5h_bn True
# 374 block5h_activation True
# 375 block5h_se_squeeze True
# 376 block5h_se_reshape True
# 377 block5h_se_reduce True
# 378 block5h_se_expand True
# 379 block5h_se_excite True
# 380 block5h_project_conv True
# 381 block5h_project_bn True
# 382 block5h_drop True
# 383 block5h_add True
# 384 block5i_expand_conv True
# 385 block5i_expand_bn True
# 386 block5i_expand_activation True
# 387 block5i_dwconv2 True
# 388 block5i_bn True
# 389 block5i_activation True
# 390 block5i_se_squeeze True
# 391 block5i_se_reshape True
# 392 block5i_se_reduce True
# 393 block5i_se_expand True
# 394 block5i_se_excite True
# 395 block5i_project_conv True
# 396 block5i_project_bn True
# 397 block5i_drop True
# 398 block5i_add True
# 399 block5j_expand_conv True
# 400 block5j_expand_bn True
# 401 block5j_expand_activation True
# 402 block5j_dwconv2 True
# 403 block5j_bn True
# 404 block5j_activation True
# 405 block5j_se_squeeze True
# 406 block5j_se_reshape True
# 407 block5j_se_reduce True
# 408 block5j_se_expand True
# 409 block5j_se_excite True
# 410 block5j_project_conv True
# 411 block5j_project_bn True
# 412 block5j_drop True
# 413 block5j_add True
# 414 block5k_expand_conv True
# 415 block5k_expand_bn True
# 416 block5k_expand_activation True
# 417 block5k_dwconv2 True
# 418 block5k_bn True
# 419 block5k_activation True
# 420 block5k_se_squeeze True
# 421 block5k_se_reshape True
# 422 block5k_se_reduce True
# 423 block5k_se_expand True
# 424 block5k_se_excite True
# 425 block5k_project_conv True
# 426 block5k_project_bn True
# 427 block5k_drop True
# 428 block5k_add True
# 429 block5l_expand_conv True
# 430 block5l_expand_bn True
# 431 block5l_expand_activation True
# 432 block5l_dwconv2 True
# 433 block5l_bn True
# 434 block5l_activation True
# 435 block5l_se_squeeze True
# 436 block5l_se_reshape True
# 437 block5l_se_reduce True
# 438 block5l_se_expand True
# 439 block5l_se_excite True
# 440 block5l_project_conv True
# 441 block5l_project_bn True
# 442 block5l_drop True
# 443 block5l_add True
# 444 block5m_expand_conv True
# 445 block5m_expand_bn True
# 446 block5m_expand_activation True
# 447 block5m_dwconv2 True
# 448 block5m_bn True
# 449 block5m_activation True
# 450 block5m_se_squeeze True
# 451 block5m_se_reshape True
# 452 block5m_se_reduce True
# 453 block5m_se_expand True
# 454 block5m_se_excite True
# 455 block5m_project_conv True
# 456 block5m_project_bn True
# 457 block5m_drop True
# 458 block5m_add True
# 459 block5n_expand_conv True
# 460 block5n_expand_bn True
# 461 block5n_expand_activation True
# 462 block5n_dwconv2 True
# 463 block5n_bn True
# 464 block5n_activation True
# 465 block5n_se_squeeze True
# 466 block5n_se_reshape True
# 467 block5n_se_reduce True
# 468 block5n_se_expand True
# 469 block5n_se_excite True
# 470 block5n_project_conv True
# 471 block5n_project_bn True
# 472 block5n_drop True
# 473 block5n_add True
# 474 block5o_expand_conv True
# 475 block5o_expand_bn True
# 476 block5o_expand_activation True
# 477 block5o_dwconv2 True
# 478 block5o_bn True
# 479 block5o_activation True
# 480 block5o_se_squeeze True
# 481 block5o_se_reshape True
# 482 block5o_se_reduce True
# 483 block5o_se_expand True
# 484 block5o_se_excite True
# 485 block5o_project_conv True
# 486 block5o_project_bn True
# 487 block5o_drop True
# 488 block5o_add True
# 489 block5p_expand_conv True
# 490 block5p_expand_bn True
# 491 block5p_expand_activation True
# 492 block5p_dwconv2 True
# 493 block5p_bn True
# 494 block5p_activation True
# 495 block5p_se_squeeze True
# 496 block5p_se_reshape True
# 497 block5p_se_reduce True
# 498 block5p_se_expand True
# 499 block5p_se_excite True
# 500 block5p_project_conv True
# 501 block5p_project_bn True
# 502 block5p_drop True
# 503 block5p_add True
# 504 block5q_expand_conv True
# 505 block5q_expand_bn True
# 506 block5q_expand_activation True
# 507 block5q_dwconv2 True
# 508 block5q_bn True
# 509 block5q_activation True
# 510 block5q_se_squeeze True
# 511 block5q_se_reshape True
# 512 block5q_se_reduce True
# 513 block5q_se_expand True
# 514 block5q_se_excite True
# 515 block5q_project_conv True
# 516 block5q_project_bn True
# 517 block5q_drop True
# 518 block5q_add True
# 519 block5r_expand_conv True
# 520 block5r_expand_bn True
# 521 block5r_expand_activation True
# 522 block5r_dwconv2 True
# 523 block5r_bn True
# 524 block5r_activation True
# 525 block5r_se_squeeze True
# 526 block5r_se_reshape True
# 527 block5r_se_reduce True
# 528 block5r_se_expand True
# 529 block5r_se_excite True
# 530 block5r_project_conv True
# 531 block5r_project_bn True
# 532 block5r_drop True
# 533 block5r_add True
# 534 block5s_expand_conv True
# 535 block5s_expand_bn True
# 536 block5s_expand_activation True
# 537 block5s_dwconv2 True
# 538 block5s_bn True
# 539 block5s_activation True
# 540 block5s_se_squeeze True
# 541 block5s_se_reshape True
# 542 block5s_se_reduce True
# 543 block5s_se_expand True
# 544 block5s_se_excite True
# 545 block5s_project_conv True
# 546 block5s_project_bn True
# 547 block5s_drop True
# 548 block5s_add True
# 549 block6a_expand_conv True
# 550 block6a_expand_bn True
# 551 block6a_expand_activation True
# 552 block6a_dwconv2 True
# 553 block6a_bn True
# 554 block6a_activation True
# 555 block6a_se_squeeze True
# 556 block6a_se_reshape True
# 557 block6a_se_reduce True
# 558 block6a_se_expand True
# 559 block6a_se_excite True
# 560 block6a_project_conv True
# 561 block6a_project_bn True
# 562 block6b_expand_conv True
# 563 block6b_expand_bn True
# 564 block6b_expand_activation True
# 565 block6b_dwconv2 True
# 566 block6b_bn True
# 567 block6b_activation True
# 568 block6b_se_squeeze True
# 569 block6b_se_reshape True
# 570 block6b_se_reduce True
# 571 block6b_se_expand True
# 572 block6b_se_excite True
# 573 block6b_project_conv True
# 574 block6b_project_bn True
# 575 block6b_drop True
# 576 block6b_add True
# 577 block6c_expand_conv True
# 578 block6c_expand_bn True
# 579 block6c_expand_activation True
# 580 block6c_dwconv2 True
# 581 block6c_bn True
# 582 block6c_activation True
# 583 block6c_se_squeeze True
# 584 block6c_se_reshape True
# 585 block6c_se_reduce True
# 586 block6c_se_expand True
# 587 block6c_se_excite True
# 588 block6c_project_conv True
# 589 block6c_project_bn True
# 590 block6c_drop True
# 591 block6c_add True
# 592 block6d_expand_conv True
# 593 block6d_expand_bn True
# 594 block6d_expand_activation True
# 595 block6d_dwconv2 True
# 596 block6d_bn True
# 597 block6d_activation True
# 598 block6d_se_squeeze True
# 599 block6d_se_reshape True
# 600 block6d_se_reduce True
# 601 block6d_se_expand True
# 602 block6d_se_excite True
# 603 block6d_project_conv True
# 604 block6d_project_bn True
# 605 block6d_drop True
# 606 block6d_add True
# 607 block6e_expand_conv True
# 608 block6e_expand_bn True
# 609 block6e_expand_activation True
# 610 block6e_dwconv2 True
# 611 block6e_bn True
# 612 block6e_activation True
# 613 block6e_se_squeeze True
# 614 block6e_se_reshape True
# 615 block6e_se_reduce True
# 616 block6e_se_expand True
# 617 block6e_se_excite True
# 618 block6e_project_conv True
# 619 block6e_project_bn True
# 620 block6e_drop True
# 621 block6e_add True
# 622 block6f_expand_conv True
# 623 block6f_expand_bn True
# 624 block6f_expand_activation True
# 625 block6f_dwconv2 True
# 626 block6f_bn True
# 627 block6f_activation True
# 628 block6f_se_squeeze True
# 629 block6f_se_reshape True
# 630 block6f_se_reduce True
# 631 block6f_se_expand True
# 632 block6f_se_excite True
# 633 block6f_project_conv True
# 634 block6f_project_bn True
# 635 block6f_drop True
# 636 block6f_add True
# 637 block6g_expand_conv True
# 638 block6g_expand_bn True
# 639 block6g_expand_activation True
# 640 block6g_dwconv2 True
# 641 block6g_bn True
# 642 block6g_activation True
# 643 block6g_se_squeeze True
# 644 block6g_se_reshape True
# 645 block6g_se_reduce True
# 646 block6g_se_expand True
# 647 block6g_se_excite True
# 648 block6g_project_conv True
# 649 block6g_project_bn True
# 650 block6g_drop True
# 651 block6g_add True
# 652 block6h_expand_conv True
# 653 block6h_expand_bn True
# 654 block6h_expand_activation True
# 655 block6h_dwconv2 True
# 656 block6h_bn True
# 657 block6h_activation True
# 658 block6h_se_squeeze True
# 659 block6h_se_reshape True
# 660 block6h_se_reduce True
# 661 block6h_se_expand True
# 662 block6h_se_excite True
# 663 block6h_project_conv True
# 664 block6h_project_bn True
# 665 block6h_drop True
# 666 block6h_add True
# 667 block6i_expand_conv True
# 668 block6i_expand_bn True
# 669 block6i_expand_activation True
# 670 block6i_dwconv2 True
# 671 block6i_bn True
# 672 block6i_activation True
# 673 block6i_se_squeeze True
# 674 block6i_se_reshape True
# 675 block6i_se_reduce True
# 676 block6i_se_expand True
# 677 block6i_se_excite True
# 678 block6i_project_conv True
# 679 block6i_project_bn True
# 680 block6i_drop True
# 681 block6i_add True
# 682 block6j_expand_conv True
# 683 block6j_expand_bn True
# 684 block6j_expand_activation True
# 685 block6j_dwconv2 True
# 686 block6j_bn True
# 687 block6j_activation True
# 688 block6j_se_squeeze True
# 689 block6j_se_reshape True
# 690 block6j_se_reduce True
# 691 block6j_se_expand True
# 692 block6j_se_excite True
# 693 block6j_project_conv True
# 694 block6j_project_bn True
# 695 block6j_drop True
# 696 block6j_add True
# 697 block6k_expand_conv True
# 698 block6k_expand_bn True
# 699 block6k_expand_activation True
# 700 block6k_dwconv2 True
# 701 block6k_bn True
# 702 block6k_activation True
# 703 block6k_se_squeeze True
# 704 block6k_se_reshape True
# 705 block6k_se_reduce True
# 706 block6k_se_expand True
# 707 block6k_se_excite True
# 708 block6k_project_conv True
# 709 block6k_project_bn True
# 710 block6k_drop True
# 711 block6k_add True
# 712 block6l_expand_conv True
# 713 block6l_expand_bn True
# 714 block6l_expand_activation True
# 715 block6l_dwconv2 True
# 716 block6l_bn True
# 717 block6l_activation True
# 718 block6l_se_squeeze True
# 719 block6l_se_reshape True
# 720 block6l_se_reduce True
# 721 block6l_se_expand True
# 722 block6l_se_excite True
# 723 block6l_project_conv True
# 724 block6l_project_bn True
# 725 block6l_drop True
# 726 block6l_add True
# 727 block6m_expand_conv True
# 728 block6m_expand_bn True
# 729 block6m_expand_activation True
# 730 block6m_dwconv2 True
# 731 block6m_bn True
# 732 block6m_activation True
# 733 block6m_se_squeeze True
# 734 block6m_se_reshape True
# 735 block6m_se_reduce True
# 736 block6m_se_expand True
# 737 block6m_se_excite True
# 738 block6m_project_conv True
# 739 block6m_project_bn True
# 740 block6m_drop True
# 741 block6m_add True
# 742 block6n_expand_conv True
# 743 block6n_expand_bn True
# 744 block6n_expand_activation True
# 745 block6n_dwconv2 True
# 746 block6n_bn True
# 747 block6n_activation True
# 748 block6n_se_squeeze True
# 749 block6n_se_reshape True
# 750 block6n_se_reduce True
# 751 block6n_se_expand True
# 752 block6n_se_excite True
# 753 block6n_project_conv True
# 754 block6n_project_bn True
# 755 block6n_drop True
# 756 block6n_add True
# 757 block6o_expand_conv True
# 758 block6o_expand_bn True
# 759 block6o_expand_activation True
# 760 block6o_dwconv2 True
# 761 block6o_bn True
# 762 block6o_activation True
# 763 block6o_se_squeeze True
# 764 block6o_se_reshape True
# 765 block6o_se_reduce True
# 766 block6o_se_expand True
# 767 block6o_se_excite True
# 768 block6o_project_conv True
# 769 block6o_project_bn True
# 770 block6o_drop True
# 771 block6o_add True
# 772 block6p_expand_conv True
# 773 block6p_expand_bn True
# 774 block6p_expand_activation True
# 775 block6p_dwconv2 True
# 776 block6p_bn True
# 777 block6p_activation True
# 778 block6p_se_squeeze True
# 779 block6p_se_reshape True
# 780 block6p_se_reduce True
# 781 block6p_se_expand True
# 782 block6p_se_excite True
# 783 block6p_project_conv True
# 784 block6p_project_bn True
# 785 block6p_drop True
# 786 block6p_add True
# 787 block6q_expand_conv True
# 788 block6q_expand_bn True
# 789 block6q_expand_activation True
# 790 block6q_dwconv2 True
# 791 block6q_bn True
# 792 block6q_activation True
# 793 block6q_se_squeeze True
# 794 block6q_se_reshape True
# 795 block6q_se_reduce True
# 796 block6q_se_expand True
# 797 block6q_se_excite True
# 798 block6q_project_conv True
# 799 block6q_project_bn True
# 800 block6q_drop True
# 801 block6q_add True
# 802 block6r_expand_conv True
# 803 block6r_expand_bn True
# 804 block6r_expand_activation True
# 805 block6r_dwconv2 True
# 806 block6r_bn True
# 807 block6r_activation True
# 808 block6r_se_squeeze True
# 809 block6r_se_reshape True
# 810 block6r_se_reduce True
# 811 block6r_se_expand True
# 812 block6r_se_excite True
# 813 block6r_project_conv True
# 814 block6r_project_bn True
# 815 block6r_drop True
# 816 block6r_add True
# 817 block6s_expand_conv True
# 818 block6s_expand_bn True
# 819 block6s_expand_activation True
# 820 block6s_dwconv2 True
# 821 block6s_bn True
# 822 block6s_activation True
# 823 block6s_se_squeeze True
# 824 block6s_se_reshape True
# 825 block6s_se_reduce True
# 826 block6s_se_expand True
# 827 block6s_se_excite True
# 828 block6s_project_conv True
# 829 block6s_project_bn True
# 830 block6s_drop True
# 831 block6s_add True
# 832 block6t_expand_conv True
# 833 block6t_expand_bn True
# 834 block6t_expand_activation True
# 835 block6t_dwconv2 True
# 836 block6t_bn True
# 837 block6t_activation True
# 838 block6t_se_squeeze True
# 839 block6t_se_reshape True
# 840 block6t_se_reduce True
# 841 block6t_se_expand True
# 842 block6t_se_excite True
# 843 block6t_project_conv True
# 844 block6t_project_bn True
# 845 block6t_drop True
# 846 block6t_add True
# 847 block6u_expand_conv True
# 848 block6u_expand_bn True
# 849 block6u_expand_activation True
# 850 block6u_dwconv2 True
# 851 block6u_bn True
# 852 block6u_activation True
# 853 block6u_se_squeeze True
# 854 block6u_se_reshape True
# 855 block6u_se_reduce True
# 856 block6u_se_expand True
# 857 block6u_se_excite True
# 858 block6u_project_conv True
# 859 block6u_project_bn True
# 860 block6u_drop True
# 861 block6u_add True
# 862 block6v_expand_conv True
# 863 block6v_expand_bn True
# 864 block6v_expand_activation True
# 865 block6v_dwconv2 True
# 866 block6v_bn True
# 867 block6v_activation True
# 868 block6v_se_squeeze True
# 869 block6v_se_reshape True
# 870 block6v_se_reduce True
# 871 block6v_se_expand True
# 872 block6v_se_excite True
# 873 block6v_project_conv True
# 874 block6v_project_bn True
# 875 block6v_drop True
# 876 block6v_add True
# 877 block6w_expand_conv True
# 878 block6w_expand_bn True
# 879 block6w_expand_activation True
# 880 block6w_dwconv2 True
# 881 block6w_bn True
# 882 block6w_activation True
# 883 block6w_se_squeeze True
# 884 block6w_se_reshape True
# 885 block6w_se_reduce True
# 886 block6w_se_expand True
# 887 block6w_se_excite True
# 888 block6w_project_conv True
# 889 block6w_project_bn True
# 890 block6w_drop True
# 891 block6w_add True
# 892 block6x_expand_conv True
# 893 block6x_expand_bn True
# 894 block6x_expand_activation True
# 895 block6x_dwconv2 True
# 896 block6x_bn True
# 897 block6x_activation True
# 898 block6x_se_squeeze True
# 899 block6x_se_reshape True
# 900 block6x_se_reduce True
# 901 block6x_se_expand True
# 902 block6x_se_excite True
# 903 block6x_project_conv True
# 904 block6x_project_bn True
# 905 block6x_drop True
# 906 block6x_add True
# 907 block6y_expand_conv True
# 908 block6y_expand_bn True
# 909 block6y_expand_activation True
# 910 block6y_dwconv2 True
# 911 block6y_bn True
# 912 block6y_activation True
# 913 block6y_se_squeeze True
# 914 block6y_se_reshape True
# 915 block6y_se_reduce True
# 916 block6y_se_expand True
# 917 block6y_se_excite True
# 918 block6y_project_conv True
# 919 block6y_project_bn True
# 920 block6y_drop True
# 921 block6y_add True
# 922 block7a_expand_conv True
# 923 block7a_expand_bn True
# 924 block7a_expand_activation True
# 925 block7a_dwconv2 True
# 926 block7a_bn True
# 927 block7a_activation True
# 928 block7a_se_squeeze True
# 929 block7a_se_reshape True
# 930 block7a_se_reduce True
# 931 block7a_se_expand True
# 932 block7a_se_excite True
# 933 block7a_project_conv True
# 934 block7a_project_bn True
# 935 block7b_expand_conv True
# 936 block7b_expand_bn True
# 937 block7b_expand_activation True
# 938 block7b_dwconv2 True
# 939 block7b_bn True
# 940 block7b_activation True
# 941 block7b_se_squeeze True
# 942 block7b_se_reshape True
# 943 block7b_se_reduce True
# 944 block7b_se_expand True
# 945 block7b_se_excite True
# 946 block7b_project_conv True
# 947 block7b_project_bn True
# 948 block7b_drop True
# 949 block7b_add True
# 950 block7c_expand_conv True
# 951 block7c_expand_bn True
# 952 block7c_expand_activation True
# 953 block7c_dwconv2 True
# 954 block7c_bn True
# 955 block7c_activation True
# 956 block7c_se_squeeze True
# 957 block7c_se_reshape True
# 958 block7c_se_reduce True
# 959 block7c_se_expand True
# 960 block7c_se_excite True
# 961 block7c_project_conv True
# 962 block7c_project_bn True
# 963 block7c_drop True
# 964 block7c_add True
# 965 block7d_expand_conv True
# 966 block7d_expand_bn True
# 967 block7d_expand_activation True
# 968 block7d_dwconv2 True
# 969 block7d_bn True
# 970 block7d_activation True
# 971 block7d_se_squeeze True
# 972 block7d_se_reshape True
# 973 block7d_se_reduce True
# 974 block7d_se_expand True
# 975 block7d_se_excite True
# 976 block7d_project_conv True
# 977 block7d_project_bn True
# 978 block7d_drop True
# 979 block7d_add True
# 980 block7e_expand_conv True
# 981 block7e_expand_bn True
# 982 block7e_expand_activation True
# 983 block7e_dwconv2 True
# 984 block7e_bn True
# 985 block7e_activation True
# 986 block7e_se_squeeze True
# 987 block7e_se_reshape True
# 988 block7e_se_reduce True
# 989 block7e_se_expand True
# 990 block7e_se_excite True
# 991 block7e_project_conv True
# 992 block7e_project_bn True
# 993 block7e_drop True
# 994 block7e_add True
# 995 block7f_expand_conv True
# 996 block7f_expand_bn True
# 997 block7f_expand_activation True
# 998 block7f_dwconv2 True
# 999 block7f_bn True
# 1000 block7f_activation True
# 1001 block7f_se_squeeze True
# 1002 block7f_se_reshape True
# 1003 block7f_se_reduce True
# 1004 block7f_se_expand True
# 1005 block7f_se_excite True
# 1006 block7f_project_conv True
# 1007 block7f_project_bn True
# 1008 block7f_drop True
# 1009 block7f_add True
# 1010 block7g_expand_conv True
# 1011 block7g_expand_bn True
# 1012 block7g_expand_activation True
# 1013 block7g_dwconv2 True
# 1014 block7g_bn True
# 1015 block7g_activation True
# 1016 block7g_se_squeeze True
# 1017 block7g_se_reshape True
# 1018 block7g_se_reduce True
# 1019 block7g_se_expand True
# 1020 block7g_se_excite True
# 1021 block7g_project_conv True
# 1022 block7g_project_bn True
# 1023 block7g_drop True
# 1024 block7g_add True
# 1025 top_conv True
# 1026 top_bn True
# 1027 top_activation True
# 1028 avg_pool True

# %%
# Freeze first N layers, e.g., until the 133rd one
#meno layer??
#N = 71
#N = 256
N = 526
for i, layer in enumerate(ft2_model.get_layer('efficientnetv2-l').layers[:N]):
  layer.trainable=False
for i, layer in enumerate(ft2_model.get_layer('efficientnetv2-l').layers):
   print(i, layer.name, layer.trainable)
ft2_model.summary()

# Compile the model with Categorical Cross-Entropy loss and Adam optimizer
ft2_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-5), metrics=['accuracy'])
# Out:
# 0 input_1 False
# 1 rescaling False
# 2 stem_conv False
# 3 stem_bn False
# 4 stem_activation False
# 5 block1a_project_conv False
# 6 block1a_project_bn False
# 7 block1a_project_activation False
# 8 block1a_add False
# 9 block1b_project_conv False
# 10 block1b_project_bn False
# 11 block1b_project_activation False
# 12 block1b_drop False
# 13 block1b_add False
# 14 block1c_project_conv False
# 15 block1c_project_bn False
# 16 block1c_project_activation False
# 17 block1c_drop False
# 18 block1c_add False
# 19 block1d_project_conv False
# 20 block1d_project_bn False
# 21 block1d_project_activation False
# 22 block1d_drop False
# 23 block1d_add False
# 24 block2a_expand_conv False
# 25 block2a_expand_bn False
# 26 block2a_expand_activation False
# 27 block2a_project_conv False
# 28 block2a_project_bn False
# 29 block2b_expand_conv False
# 30 block2b_expand_bn False
# 31 block2b_expand_activation False
# 32 block2b_project_conv False
# 33 block2b_project_bn False
# 34 block2b_drop False
# 35 block2b_add False
# 36 block2c_expand_conv False
# 37 block2c_expand_bn False
# 38 block2c_expand_activation False
# 39 block2c_project_conv False
# 40 block2c_project_bn False
# 41 block2c_drop False
# 42 block2c_add False
# 43 block2d_expand_conv False
# 44 block2d_expand_bn False
# 45 block2d_expand_activation False
# 46 block2d_project_conv False
# 47 block2d_project_bn False
# 48 block2d_drop False
# 49 block2d_add False
# 50 block2e_expand_conv False
# 51 block2e_expand_bn False
# 52 block2e_expand_activation False
# 53 block2e_project_conv False
# 54 block2e_project_bn False
# 55 block2e_drop False
# 56 block2e_add False
# 57 block2f_expand_conv False
# 58 block2f_expand_bn False
# 59 block2f_expand_activation False
# 60 block2f_project_conv False
# 61 block2f_project_bn False
# 62 block2f_drop False
# 63 block2f_add False
# 64 block2g_expand_conv False
# 65 block2g_expand_bn False
# 66 block2g_expand_activation False
# 67 block2g_project_conv False
# 68 block2g_project_bn False
# 69 block2g_drop False
# 70 block2g_add False
# 71 block3a_expand_conv False
# 72 block3a_expand_bn False
# 73 block3a_expand_activation False
# 74 block3a_project_conv False
# 75 block3a_project_bn False
# 76 block3b_expand_conv False
# 77 block3b_expand_bn False
# 78 block3b_expand_activation False
# 79 block3b_project_conv False
# 80 block3b_project_bn False
# 81 block3b_drop False
# 82 block3b_add False
# 83 block3c_expand_conv False
# 84 block3c_expand_bn False
# 85 block3c_expand_activation False
# 86 block3c_project_conv False
# 87 block3c_project_bn False
# 88 block3c_drop False
# 89 block3c_add False
# 90 block3d_expand_conv False
# 91 block3d_expand_bn False
# 92 block3d_expand_activation False
# 93 block3d_project_conv False
# 94 block3d_project_bn False
# 95 block3d_drop False
# 96 block3d_add False
# 97 block3e_expand_conv False
# 98 block3e_expand_bn False
# 99 block3e_expand_activation False
# 100 block3e_project_conv False
# 101 block3e_project_bn False
# 102 block3e_drop False
# 103 block3e_add False
# 104 block3f_expand_conv False
# 105 block3f_expand_bn False
# 106 block3f_expand_activation False
# 107 block3f_project_conv False
# 108 block3f_project_bn False
# 109 block3f_drop False
# 110 block3f_add False
# 111 block3g_expand_conv False
# 112 block3g_expand_bn False
# 113 block3g_expand_activation False
# 114 block3g_project_conv False
# 115 block3g_project_bn False
# 116 block3g_drop False
# 117 block3g_add False
# 118 block4a_expand_conv False
# 119 block4a_expand_bn False
# 120 block4a_expand_activation False
# 121 block4a_dwconv2 False
# 122 block4a_bn False
# 123 block4a_activation False
# 124 block4a_se_squeeze False
# 125 block4a_se_reshape False
# 126 block4a_se_reduce False
# 127 block4a_se_expand False
# 128 block4a_se_excite False
# 129 block4a_project_conv False
# 130 block4a_project_bn False
# 131 block4b_expand_conv False
# 132 block4b_expand_bn False
# 133 block4b_expand_activation False
# 134 block4b_dwconv2 False
# 135 block4b_bn False
# 136 block4b_activation False
# 137 block4b_se_squeeze False
# 138 block4b_se_reshape False
# 139 block4b_se_reduce False
# 140 block4b_se_expand False
# 141 block4b_se_excite False
# 142 block4b_project_conv False
# 143 block4b_project_bn False
# 144 block4b_drop False
# 145 block4b_add False
# 146 block4c_expand_conv False
# 147 block4c_expand_bn False
# 148 block4c_expand_activation False
# 149 block4c_dwconv2 False
# 150 block4c_bn False
# 151 block4c_activation False
# 152 block4c_se_squeeze False
# 153 block4c_se_reshape False
# 154 block4c_se_reduce False
# 155 block4c_se_expand False
# 156 block4c_se_excite False
# 157 block4c_project_conv False
# 158 block4c_project_bn False
# 159 block4c_drop False
# 160 block4c_add False
# 161 block4d_expand_conv False
# 162 block4d_expand_bn False
# 163 block4d_expand_activation False
# 164 block4d_dwconv2 False
# 165 block4d_bn False
# 166 block4d_activation False
# 167 block4d_se_squeeze False
# 168 block4d_se_reshape False
# 169 block4d_se_reduce False
# 170 block4d_se_expand False
# 171 block4d_se_excite False
# 172 block4d_project_conv False
# 173 block4d_project_bn False
# 174 block4d_drop False
# 175 block4d_add False
# 176 block4e_expand_conv False
# 177 block4e_expand_bn False
# 178 block4e_expand_activation False
# 179 block4e_dwconv2 False
# 180 block4e_bn False
# 181 block4e_activation False
# 182 block4e_se_squeeze False
# 183 block4e_se_reshape False
# 184 block4e_se_reduce False
# 185 block4e_se_expand False
# 186 block4e_se_excite False
# 187 block4e_project_conv False
# 188 block4e_project_bn False
# 189 block4e_drop False
# 190 block4e_add False
# 191 block4f_expand_conv False
# 192 block4f_expand_bn False
# 193 block4f_expand_activation False
# 194 block4f_dwconv2 False
# 195 block4f_bn False
# 196 block4f_activation False
# 197 block4f_se_squeeze False
# 198 block4f_se_reshape False
# 199 block4f_se_reduce False
# 200 block4f_se_expand False
# 201 block4f_se_excite False
# 202 block4f_project_conv False
# 203 block4f_project_bn False
# 204 block4f_drop False
# 205 block4f_add False
# 206 block4g_expand_conv False
# 207 block4g_expand_bn False
# 208 block4g_expand_activation False
# 209 block4g_dwconv2 False
# 210 block4g_bn False
# 211 block4g_activation False
# 212 block4g_se_squeeze False
# 213 block4g_se_reshape False
# 214 block4g_se_reduce False
# 215 block4g_se_expand False
# 216 block4g_se_excite False
# 217 block4g_project_conv False
# 218 block4g_project_bn False
# 219 block4g_drop False
# 220 block4g_add False
# 221 block4h_expand_conv False
# 222 block4h_expand_bn False
# 223 block4h_expand_activation False
# 224 block4h_dwconv2 False
# 225 block4h_bn False
# 226 block4h_activation False
# 227 block4h_se_squeeze False
# 228 block4h_se_reshape False
# 229 block4h_se_reduce False
# 230 block4h_se_expand False
# 231 block4h_se_excite False
# 232 block4h_project_conv False
# 233 block4h_project_bn False
# 234 block4h_drop False
# 235 block4h_add False
# 236 block4i_expand_conv False
# 237 block4i_expand_bn False
# 238 block4i_expand_activation False
# 239 block4i_dwconv2 False
# 240 block4i_bn False
# 241 block4i_activation False
# 242 block4i_se_squeeze False
# 243 block4i_se_reshape False
# 244 block4i_se_reduce False
# 245 block4i_se_expand False
# 246 block4i_se_excite False
# 247 block4i_project_conv False
# 248 block4i_project_bn False
# 249 block4i_drop False
# 250 block4i_add False
# 251 block4j_expand_conv False
# 252 block4j_expand_bn False
# 253 block4j_expand_activation False
# 254 block4j_dwconv2 False
# 255 block4j_bn False
# 256 block4j_activation False
# 257 block4j_se_squeeze False
# 258 block4j_se_reshape False
# 259 block4j_se_reduce False
# 260 block4j_se_expand False
# 261 block4j_se_excite False
# 262 block4j_project_conv False
# 263 block4j_project_bn False
# 264 block4j_drop False
# 265 block4j_add False
# 266 block5a_expand_conv False
# 267 block5a_expand_bn False
# 268 block5a_expand_activation False
# 269 block5a_dwconv2 False
# 270 block5a_bn False
# 271 block5a_activation False
# 272 block5a_se_squeeze False
# 273 block5a_se_reshape False
# 274 block5a_se_reduce False
# 275 block5a_se_expand False
# 276 block5a_se_excite False
# 277 block5a_project_conv False
# 278 block5a_project_bn False
# 279 block5b_expand_conv False
# 280 block5b_expand_bn False
# 281 block5b_expand_activation False
# 282 block5b_dwconv2 False
# 283 block5b_bn False
# 284 block5b_activation False
# 285 block5b_se_squeeze False
# 286 block5b_se_reshape False
# 287 block5b_se_reduce False
# 288 block5b_se_expand False
# 289 block5b_se_excite False
# 290 block5b_project_conv False
# 291 block5b_project_bn False
# 292 block5b_drop False
# 293 block5b_add False
# 294 block5c_expand_conv False
# 295 block5c_expand_bn False
# 296 block5c_expand_activation False
# 297 block5c_dwconv2 False
# 298 block5c_bn False
# 299 block5c_activation False
# 300 block5c_se_squeeze False
# 301 block5c_se_reshape False
# 302 block5c_se_reduce False
# 303 block5c_se_expand False
# 304 block5c_se_excite False
# 305 block5c_project_conv False
# 306 block5c_project_bn False
# 307 block5c_drop False
# 308 block5c_add False
# 309 block5d_expand_conv False
# 310 block5d_expand_bn False
# 311 block5d_expand_activation False
# 312 block5d_dwconv2 False
# 313 block5d_bn False
# 314 block5d_activation False
# 315 block5d_se_squeeze False
# 316 block5d_se_reshape False
# 317 block5d_se_reduce False
# 318 block5d_se_expand False
# 319 block5d_se_excite False
# 320 block5d_project_conv False
# 321 block5d_project_bn False
# 322 block5d_drop False
# 323 block5d_add False
# 324 block5e_expand_conv False
# 325 block5e_expand_bn False
# 326 block5e_expand_activation False
# 327 block5e_dwconv2 False
# 328 block5e_bn False
# 329 block5e_activation False
# 330 block5e_se_squeeze False
# 331 block5e_se_reshape False
# 332 block5e_se_reduce False
# 333 block5e_se_expand False
# 334 block5e_se_excite False
# 335 block5e_project_conv False
# 336 block5e_project_bn False
# 337 block5e_drop False
# 338 block5e_add False
# 339 block5f_expand_conv False
# 340 block5f_expand_bn False
# 341 block5f_expand_activation False
# 342 block5f_dwconv2 False
# 343 block5f_bn False
# 344 block5f_activation False
# 345 block5f_se_squeeze False
# 346 block5f_se_reshape False
# 347 block5f_se_reduce False
# 348 block5f_se_expand False
# 349 block5f_se_excite False
# 350 block5f_project_conv False
# 351 block5f_project_bn False
# 352 block5f_drop False
# 353 block5f_add False
# 354 block5g_expand_conv False
# 355 block5g_expand_bn False
# 356 block5g_expand_activation False
# 357 block5g_dwconv2 False
# 358 block5g_bn False
# 359 block5g_activation False
# 360 block5g_se_squeeze False
# 361 block5g_se_reshape False
# 362 block5g_se_reduce False
# 363 block5g_se_expand False
# 364 block5g_se_excite False
# 365 block5g_project_conv False
# 366 block5g_project_bn False
# 367 block5g_drop False
# 368 block5g_add False
# 369 block5h_expand_conv False
# 370 block5h_expand_bn False
# 371 block5h_expand_activation False
# 372 block5h_dwconv2 False
# 373 block5h_bn False
# 374 block5h_activation False
# 375 block5h_se_squeeze False
# 376 block5h_se_reshape False
# 377 block5h_se_reduce False
# 378 block5h_se_expand False
# 379 block5h_se_excite False
# 380 block5h_project_conv False
# 381 block5h_project_bn False
# 382 block5h_drop False
# 383 block5h_add False
# 384 block5i_expand_conv False
# 385 block5i_expand_bn False
# 386 block5i_expand_activation False
# 387 block5i_dwconv2 False
# 388 block5i_bn False
# 389 block5i_activation False
# 390 block5i_se_squeeze False
# 391 block5i_se_reshape False
# 392 block5i_se_reduce False
# 393 block5i_se_expand False
# 394 block5i_se_excite False
# 395 block5i_project_conv False
# 396 block5i_project_bn False
# 397 block5i_drop False
# 398 block5i_add False
# 399 block5j_expand_conv False
# 400 block5j_expand_bn False
# 401 block5j_expand_activation False
# 402 block5j_dwconv2 False
# 403 block5j_bn False
# 404 block5j_activation False
# 405 block5j_se_squeeze False
# 406 block5j_se_reshape False
# 407 block5j_se_reduce False
# 408 block5j_se_expand False
# 409 block5j_se_excite False
# 410 block5j_project_conv False
# 411 block5j_project_bn False
# 412 block5j_drop False
# 413 block5j_add False
# 414 block5k_expand_conv False
# 415 block5k_expand_bn False
# 416 block5k_expand_activation False
# 417 block5k_dwconv2 False
# 418 block5k_bn False
# 419 block5k_activation False
# 420 block5k_se_squeeze False
# 421 block5k_se_reshape False
# 422 block5k_se_reduce False
# 423 block5k_se_expand False
# 424 block5k_se_excite False
# 425 block5k_project_conv False
# 426 block5k_project_bn False
# 427 block5k_drop False
# 428 block5k_add False
# 429 block5l_expand_conv False
# 430 block5l_expand_bn False
# 431 block5l_expand_activation False
# 432 block5l_dwconv2 False
# 433 block5l_bn False
# 434 block5l_activation False
# 435 block5l_se_squeeze False
# 436 block5l_se_reshape False
# 437 block5l_se_reduce False
# 438 block5l_se_expand False
# 439 block5l_se_excite False
# 440 block5l_project_conv False
# 441 block5l_project_bn False
# 442 block5l_drop False
# 443 block5l_add False
# 444 block5m_expand_conv False
# 445 block5m_expand_bn False
# 446 block5m_expand_activation False
# 447 block5m_dwconv2 False
# 448 block5m_bn False
# 449 block5m_activation False
# 450 block5m_se_squeeze False
# 451 block5m_se_reshape False
# 452 block5m_se_reduce False
# 453 block5m_se_expand False
# 454 block5m_se_excite False
# 455 block5m_project_conv False
# 456 block5m_project_bn False
# 457 block5m_drop False
# 458 block5m_add False
# 459 block5n_expand_conv False
# 460 block5n_expand_bn False
# 461 block5n_expand_activation False
# 462 block5n_dwconv2 False
# 463 block5n_bn False
# 464 block5n_activation False
# 465 block5n_se_squeeze False
# 466 block5n_se_reshape False
# 467 block5n_se_reduce False
# 468 block5n_se_expand False
# 469 block5n_se_excite False
# 470 block5n_project_conv False
# 471 block5n_project_bn False
# 472 block5n_drop False
# 473 block5n_add False
# 474 block5o_expand_conv False
# 475 block5o_expand_bn False
# 476 block5o_expand_activation False
# 477 block5o_dwconv2 False
# 478 block5o_bn False
# 479 block5o_activation False
# 480 block5o_se_squeeze False
# 481 block5o_se_reshape False
# 482 block5o_se_reduce False
# 483 block5o_se_expand False
# 484 block5o_se_excite False
# 485 block5o_project_conv False
# 486 block5o_project_bn False
# 487 block5o_drop False
# 488 block5o_add False
# 489 block5p_expand_conv False
# 490 block5p_expand_bn False
# 491 block5p_expand_activation False
# 492 block5p_dwconv2 False
# 493 block5p_bn False
# 494 block5p_activation False
# 495 block5p_se_squeeze False
# 496 block5p_se_reshape False
# 497 block5p_se_reduce False
# 498 block5p_se_expand False
# 499 block5p_se_excite False
# 500 block5p_project_conv False
# 501 block5p_project_bn False
# 502 block5p_drop False
# 503 block5p_add False
# 504 block5q_expand_conv False
# 505 block5q_expand_bn False
# 506 block5q_expand_activation False
# 507 block5q_dwconv2 False
# 508 block5q_bn False
# 509 block5q_activation False
# 510 block5q_se_squeeze False
# 511 block5q_se_reshape False
# 512 block5q_se_reduce False
# 513 block5q_se_expand False
# 514 block5q_se_excite False
# 515 block5q_project_conv False
# 516 block5q_project_bn False
# 517 block5q_drop False
# 518 block5q_add False
# 519 block5r_expand_conv False
# 520 block5r_expand_bn False
# 521 block5r_expand_activation False
# 522 block5r_dwconv2 False
# 523 block5r_bn False
# 524 block5r_activation False
# 525 block5r_se_squeeze False
# 526 block5r_se_reshape True
# 527 block5r_se_reduce True
# 528 block5r_se_expand True
# 529 block5r_se_excite True
# 530 block5r_project_conv True
# 531 block5r_project_bn True
# 532 block5r_drop True
# 533 block5r_add True
# 534 block5s_expand_conv True
# 535 block5s_expand_bn True
# 536 block5s_expand_activation True
# 537 block5s_dwconv2 True
# 538 block5s_bn True
# 539 block5s_activation True
# 540 block5s_se_squeeze True
# 541 block5s_se_reshape True
# 542 block5s_se_reduce True
# 543 block5s_se_expand True
# 544 block5s_se_excite True
# 545 block5s_project_conv True
# 546 block5s_project_bn True
# 547 block5s_drop True
# 548 block5s_add True
# 549 block6a_expand_conv True
# 550 block6a_expand_bn True
# 551 block6a_expand_activation True
# 552 block6a_dwconv2 True
# 553 block6a_bn True
# 554 block6a_activation True
# 555 block6a_se_squeeze True
# 556 block6a_se_reshape True
# 557 block6a_se_reduce True
# 558 block6a_se_expand True
# 559 block6a_se_excite True
# 560 block6a_project_conv True
# 561 block6a_project_bn True
# 562 block6b_expand_conv True
# 563 block6b_expand_bn True
# 564 block6b_expand_activation True
# 565 block6b_dwconv2 True
# 566 block6b_bn True
# 567 block6b_activation True
# 568 block6b_se_squeeze True
# 569 block6b_se_reshape True
# 570 block6b_se_reduce True
# 571 block6b_se_expand True
# 572 block6b_se_excite True
# 573 block6b_project_conv True
# 574 block6b_project_bn True
# 575 block6b_drop True
# 576 block6b_add True
# 577 block6c_expand_conv True
# 578 block6c_expand_bn True
# 579 block6c_expand_activation True
# 580 block6c_dwconv2 True
# 581 block6c_bn True
# 582 block6c_activation True
# 583 block6c_se_squeeze True
# 584 block6c_se_reshape True
# 585 block6c_se_reduce True
# 586 block6c_se_expand True
# 587 block6c_se_excite True
# 588 block6c_project_conv True
# 589 block6c_project_bn True
# 590 block6c_drop True
# 591 block6c_add True
# 592 block6d_expand_conv True
# 593 block6d_expand_bn True
# 594 block6d_expand_activation True
# 595 block6d_dwconv2 True
# 596 block6d_bn True
# 597 block6d_activation True
# 598 block6d_se_squeeze True
# 599 block6d_se_reshape True
# 600 block6d_se_reduce True
# 601 block6d_se_expand True
# 602 block6d_se_excite True
# 603 block6d_project_conv True
# 604 block6d_project_bn True
# 605 block6d_drop True
# 606 block6d_add True
# 607 block6e_expand_conv True
# 608 block6e_expand_bn True
# 609 block6e_expand_activation True
# 610 block6e_dwconv2 True
# 611 block6e_bn True
# 612 block6e_activation True
# 613 block6e_se_squeeze True
# 614 block6e_se_reshape True
# 615 block6e_se_reduce True
# 616 block6e_se_expand True
# 617 block6e_se_excite True
# 618 block6e_project_conv True
# 619 block6e_project_bn True
# 620 block6e_drop True
# 621 block6e_add True
# 622 block6f_expand_conv True
# 623 block6f_expand_bn True
# 624 block6f_expand_activation True
# 625 block6f_dwconv2 True
# 626 block6f_bn True
# 627 block6f_activation True
# 628 block6f_se_squeeze True
# 629 block6f_se_reshape True
# 630 block6f_se_reduce True
# 631 block6f_se_expand True
# 632 block6f_se_excite True
# 633 block6f_project_conv True
# 634 block6f_project_bn True
# 635 block6f_drop True
# 636 block6f_add True
# 637 block6g_expand_conv True
# 638 block6g_expand_bn True
# 639 block6g_expand_activation True
# 640 block6g_dwconv2 True
# 641 block6g_bn True
# 642 block6g_activation True
# 643 block6g_se_squeeze True
# 644 block6g_se_reshape True
# 645 block6g_se_reduce True
# 646 block6g_se_expand True
# 647 block6g_se_excite True
# 648 block6g_project_conv True
# 649 block6g_project_bn True
# 650 block6g_drop True
# 651 block6g_add True
# 652 block6h_expand_conv True
# 653 block6h_expand_bn True
# 654 block6h_expand_activation True
# 655 block6h_dwconv2 True
# 656 block6h_bn True
# 657 block6h_activation True
# 658 block6h_se_squeeze True
# 659 block6h_se_reshape True
# 660 block6h_se_reduce True
# 661 block6h_se_expand True
# 662 block6h_se_excite True
# 663 block6h_project_conv True
# 664 block6h_project_bn True
# 665 block6h_drop True
# 666 block6h_add True
# 667 block6i_expand_conv True
# 668 block6i_expand_bn True
# 669 block6i_expand_activation True
# 670 block6i_dwconv2 True
# 671 block6i_bn True
# 672 block6i_activation True
# 673 block6i_se_squeeze True
# 674 block6i_se_reshape True
# 675 block6i_se_reduce True
# 676 block6i_se_expand True
# 677 block6i_se_excite True
# 678 block6i_project_conv True
# 679 block6i_project_bn True
# 680 block6i_drop True
# 681 block6i_add True
# 682 block6j_expand_conv True
# 683 block6j_expand_bn True
# 684 block6j_expand_activation True
# 685 block6j_dwconv2 True
# 686 block6j_bn True
# 687 block6j_activation True
# 688 block6j_se_squeeze True
# 689 block6j_se_reshape True
# 690 block6j_se_reduce True
# 691 block6j_se_expand True
# 692 block6j_se_excite True
# 693 block6j_project_conv True
# 694 block6j_project_bn True
# 695 block6j_drop True
# 696 block6j_add True
# 697 block6k_expand_conv True
# 698 block6k_expand_bn True
# 699 block6k_expand_activation True
# 700 block6k_dwconv2 True
# 701 block6k_bn True
# 702 block6k_activation True
# 703 block6k_se_squeeze True
# 704 block6k_se_reshape True
# 705 block6k_se_reduce True
# 706 block6k_se_expand True
# 707 block6k_se_excite True
# 708 block6k_project_conv True
# 709 block6k_project_bn True
# 710 block6k_drop True
# 711 block6k_add True
# 712 block6l_expand_conv True
# 713 block6l_expand_bn True
# 714 block6l_expand_activation True
# 715 block6l_dwconv2 True
# 716 block6l_bn True
# 717 block6l_activation True
# 718 block6l_se_squeeze True
# 719 block6l_se_reshape True
# 720 block6l_se_reduce True
# 721 block6l_se_expand True
# 722 block6l_se_excite True
# 723 block6l_project_conv True
# 724 block6l_project_bn True
# 725 block6l_drop True
# 726 block6l_add True
# 727 block6m_expand_conv True
# 728 block6m_expand_bn True
# 729 block6m_expand_activation True
# 730 block6m_dwconv2 True
# 731 block6m_bn True
# 732 block6m_activation True
# 733 block6m_se_squeeze True
# 734 block6m_se_reshape True
# 735 block6m_se_reduce True
# 736 block6m_se_expand True
# 737 block6m_se_excite True
# 738 block6m_project_conv True
# 739 block6m_project_bn True
# 740 block6m_drop True
# 741 block6m_add True
# 742 block6n_expand_conv True
# 743 block6n_expand_bn True
# 744 block6n_expand_activation True
# 745 block6n_dwconv2 True
# 746 block6n_bn True
# 747 block6n_activation True
# 748 block6n_se_squeeze True
# 749 block6n_se_reshape True
# 750 block6n_se_reduce True
# 751 block6n_se_expand True
# 752 block6n_se_excite True
# 753 block6n_project_conv True
# 754 block6n_project_bn True
# 755 block6n_drop True
# 756 block6n_add True
# 757 block6o_expand_conv True
# 758 block6o_expand_bn True
# 759 block6o_expand_activation True
# 760 block6o_dwconv2 True
# 761 block6o_bn True
# 762 block6o_activation True
# 763 block6o_se_squeeze True
# 764 block6o_se_reshape True
# 765 block6o_se_reduce True
# 766 block6o_se_expand True
# 767 block6o_se_excite True
# 768 block6o_project_conv True
# 769 block6o_project_bn True
# 770 block6o_drop True
# 771 block6o_add True
# 772 block6p_expand_conv True
# 773 block6p_expand_bn True
# 774 block6p_expand_activation True
# 775 block6p_dwconv2 True
# 776 block6p_bn True
# 777 block6p_activation True
# 778 block6p_se_squeeze True
# 779 block6p_se_reshape True
# 780 block6p_se_reduce True
# 781 block6p_se_expand True
# 782 block6p_se_excite True
# 783 block6p_project_conv True
# 784 block6p_project_bn True
# 785 block6p_drop True
# 786 block6p_add True
# 787 block6q_expand_conv True
# 788 block6q_expand_bn True
# 789 block6q_expand_activation True
# 790 block6q_dwconv2 True
# 791 block6q_bn True
# 792 block6q_activation True
# 793 block6q_se_squeeze True
# 794 block6q_se_reshape True
# 795 block6q_se_reduce True
# 796 block6q_se_expand True
# 797 block6q_se_excite True
# 798 block6q_project_conv True
# 799 block6q_project_bn True
# 800 block6q_drop True
# 801 block6q_add True
# 802 block6r_expand_conv True
# 803 block6r_expand_bn True
# 804 block6r_expand_activation True
# 805 block6r_dwconv2 True
# 806 block6r_bn True
# 807 block6r_activation True
# 808 block6r_se_squeeze True
# 809 block6r_se_reshape True
# 810 block6r_se_reduce True
# 811 block6r_se_expand True
# 812 block6r_se_excite True
# 813 block6r_project_conv True
# 814 block6r_project_bn True
# 815 block6r_drop True
# 816 block6r_add True
# 817 block6s_expand_conv True
# 818 block6s_expand_bn True
# 819 block6s_expand_activation True
# 820 block6s_dwconv2 True
# 821 block6s_bn True
# 822 block6s_activation True
# 823 block6s_se_squeeze True
# 824 block6s_se_reshape True
# 825 block6s_se_reduce True
# 826 block6s_se_expand True
# 827 block6s_se_excite True
# 828 block6s_project_conv True
# 829 block6s_project_bn True
# 830 block6s_drop True
# 831 block6s_add True
# 832 block6t_expand_conv True
# 833 block6t_expand_bn True
# 834 block6t_expand_activation True
# 835 block6t_dwconv2 True
# 836 block6t_bn True
# 837 block6t_activation True
# 838 block6t_se_squeeze True
# 839 block6t_se_reshape True
# 840 block6t_se_reduce True
# 841 block6t_se_expand True
# 842 block6t_se_excite True
# 843 block6t_project_conv True
# 844 block6t_project_bn True
# 845 block6t_drop True
# 846 block6t_add True
# 847 block6u_expand_conv True
# 848 block6u_expand_bn True
# 849 block6u_expand_activation True
# 850 block6u_dwconv2 True
# 851 block6u_bn True
# 852 block6u_activation True
# 853 block6u_se_squeeze True
# 854 block6u_se_reshape True
# 855 block6u_se_reduce True
# 856 block6u_se_expand True
# 857 block6u_se_excite True
# 858 block6u_project_conv True
# 859 block6u_project_bn True
# 860 block6u_drop True
# 861 block6u_add True
# 862 block6v_expand_conv True
# 863 block6v_expand_bn True
# 864 block6v_expand_activation True
# 865 block6v_dwconv2 True
# 866 block6v_bn True
# 867 block6v_activation True
# 868 block6v_se_squeeze True
# 869 block6v_se_reshape True
# 870 block6v_se_reduce True
# 871 block6v_se_expand True
# 872 block6v_se_excite True
# 873 block6v_project_conv True
# 874 block6v_project_bn True
# 875 block6v_drop True
# 876 block6v_add True
# 877 block6w_expand_conv True
# 878 block6w_expand_bn True
# 879 block6w_expand_activation True
# 880 block6w_dwconv2 True
# 881 block6w_bn True
# 882 block6w_activation True
# 883 block6w_se_squeeze True
# 884 block6w_se_reshape True
# 885 block6w_se_reduce True
# 886 block6w_se_expand True
# 887 block6w_se_excite True
# 888 block6w_project_conv True
# 889 block6w_project_bn True
# 890 block6w_drop True
# 891 block6w_add True
# 892 block6x_expand_conv True
# 893 block6x_expand_bn True
# 894 block6x_expand_activation True
# 895 block6x_dwconv2 True
# 896 block6x_bn True
# 897 block6x_activation True
# 898 block6x_se_squeeze True
# 899 block6x_se_reshape True
# 900 block6x_se_reduce True
# 901 block6x_se_expand True
# 902 block6x_se_excite True
# 903 block6x_project_conv True
# 904 block6x_project_bn True
# 905 block6x_drop True
# 906 block6x_add True
# 907 block6y_expand_conv True
# 908 block6y_expand_bn True
# 909 block6y_expand_activation True
# 910 block6y_dwconv2 True
# 911 block6y_bn True
# 912 block6y_activation True
# 913 block6y_se_squeeze True
# 914 block6y_se_reshape True
# 915 block6y_se_reduce True
# 916 block6y_se_expand True
# 917 block6y_se_excite True
# 918 block6y_project_conv True
# 919 block6y_project_bn True
# 920 block6y_drop True
# 921 block6y_add True
# 922 block7a_expand_conv True
# 923 block7a_expand_bn True
# 924 block7a_expand_activation True
# 925 block7a_dwconv2 True
# 926 block7a_bn True
# 927 block7a_activation True
# 928 block7a_se_squeeze True
# 929 block7a_se_reshape True
# 930 block7a_se_reduce True
# 931 block7a_se_expand True
# 932 block7a_se_excite True
# 933 block7a_project_conv True
# 934 block7a_project_bn True
# 935 block7b_expand_conv True
# 936 block7b_expand_bn True
# 937 block7b_expand_activation True
# 938 block7b_dwconv2 True
# 939 block7b_bn True
# 940 block7b_activation True
# 941 block7b_se_squeeze True
# 942 block7b_se_reshape True
# 943 block7b_se_reduce True
# 944 block7b_se_expand True
# 945 block7b_se_excite True
# 946 block7b_project_conv True
# 947 block7b_project_bn True
# 948 block7b_drop True
# 949 block7b_add True
# 950 block7c_expand_conv True
# 951 block7c_expand_bn True
# 952 block7c_expand_activation True
# 953 block7c_dwconv2 True
# 954 block7c_bn True
# 955 block7c_activation True
# 956 block7c_se_squeeze True
# 957 block7c_se_reshape True
# 958 block7c_se_reduce True
# 959 block7c_se_expand True
# 960 block7c_se_excite True
# 961 block7c_project_conv True
# 962 block7c_project_bn True
# 963 block7c_drop True
# 964 block7c_add True
# 965 block7d_expand_conv True
# 966 block7d_expand_bn True
# 967 block7d_expand_activation True
# 968 block7d_dwconv2 True
# 969 block7d_bn True
# 970 block7d_activation True
# 971 block7d_se_squeeze True
# 972 block7d_se_reshape True
# 973 block7d_se_reduce True
# 974 block7d_se_expand True
# 975 block7d_se_excite True
# 976 block7d_project_conv True
# 977 block7d_project_bn True
# 978 block7d_drop True
# 979 block7d_add True
# 980 block7e_expand_conv True
# 981 block7e_expand_bn True
# 982 block7e_expand_activation True
# 983 block7e_dwconv2 True
# 984 block7e_bn True
# 985 block7e_activation True
# 986 block7e_se_squeeze True
# 987 block7e_se_reshape True
# 988 block7e_se_reduce True
# 989 block7e_se_expand True
# 990 block7e_se_excite True
# 991 block7e_project_conv True
# 992 block7e_project_bn True
# 993 block7e_drop True
# 994 block7e_add True
# 995 block7f_expand_conv True
# 996 block7f_expand_bn True
# 997 block7f_expand_activation True
# 998 block7f_dwconv2 True
# 999 block7f_bn True
# 1000 block7f_activation True
# 1001 block7f_se_squeeze True
# 1002 block7f_se_reshape True
# 1003 block7f_se_reduce True
# 1004 block7f_se_expand True
# 1005 block7f_se_excite True
# 1006 block7f_project_conv True
# 1007 block7f_project_bn True
# 1008 block7f_drop True
# 1009 block7f_add True
# 1010 block7g_expand_conv True
# 1011 block7g_expand_bn True
# 1012 block7g_expand_activation True
# 1013 block7g_dwconv2 True
# 1014 block7g_bn True
# 1015 block7g_activation True
# 1016 block7g_se_squeeze True
# 1017 block7g_se_reshape True
# 1018 block7g_se_reduce True
# 1019 block7g_se_expand True
# 1020 block7g_se_excite True
# 1021 block7g_project_conv True
# 1022 block7g_project_bn True
# 1023 block7g_drop True
# 1024 block7g_add True
# 1025 top_conv True
# 1026 top_bn True
# 1027 top_activation True
# 1028 avg_pool True
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-l (Function  (None, 1280)              117746848
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  dropout (Dropout)           (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 120212770 (458.58 MB)
# Trainable params: 99407370 (379.21 MB)
# Non-trainable params: 20805400 (79.37 MB)
# _________________________________________________________________

# %%
# Fine-tune the model
history = ft2_model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val), 
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True),
                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)]
).history
# Out:
# Epoch 1/200
# 543/543 [==============================] - 171s 135ms/step - loss: 0.6853 - accuracy: 0.6724 - val_loss: 0.5853 - val_accuracy: 0.7002 - lr: 1.0000e-05
# Epoch 2/200
# 543/543 [==============================] - 66s 122ms/step - loss: 0.5401 - accuracy: 0.7315 - val_loss: 0.5230 - val_accuracy: 0.7521 - lr: 1.0000e-05
# Epoch 3/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.4789 - accuracy: 0.7805 - val_loss: 0.5140 - val_accuracy: 0.7801 - lr: 1.0000e-05
# Epoch 4/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.4392 - accuracy: 0.8086 - val_loss: 0.4857 - val_accuracy: 0.7936 - lr: 1.0000e-05
# Epoch 5/200
# 543/543 [==============================] - 65s 119ms/step - loss: 0.4030 - accuracy: 0.8274 - val_loss: 0.4783 - val_accuracy: 0.7988 - lr: 1.0000e-05
# Epoch 6/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.3741 - accuracy: 0.8518 - val_loss: 0.4941 - val_accuracy: 0.8019 - lr: 1.0000e-05
# Epoch 7/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.3428 - accuracy: 0.8686 - val_loss: 0.4848 - val_accuracy: 0.8112 - lr: 1.0000e-05
# Epoch 8/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.3182 - accuracy: 0.8825 - val_loss: 0.4928 - val_accuracy: 0.8257 - lr: 1.0000e-05
# Epoch 9/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.3069 - accuracy: 0.8890 - val_loss: 0.5142 - val_accuracy: 0.8060 - lr: 1.0000e-05
# Epoch 10/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.2871 - accuracy: 0.8980 - val_loss: 0.4985 - val_accuracy: 0.8164 - lr: 1.0000e-05
# Epoch 11/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.2626 - accuracy: 0.9160 - val_loss: 0.4872 - val_accuracy: 0.8164 - lr: 5.0000e-06
# Epoch 12/200
# 543/543 [==============================] - 67s 123ms/step - loss: 0.2535 - accuracy: 0.9207 - val_loss: 0.5126 - val_accuracy: 0.8205 - lr: 5.0000e-06
# Epoch 13/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.2428 - accuracy: 0.9236 - val_loss: 0.4965 - val_accuracy: 0.8288 - lr: 5.0000e-06
# Epoch 14/200
# 543/543 [==============================] - 65s 120ms/step - loss: 0.2397 - accuracy: 0.9239 - val_loss: 0.5236 - val_accuracy: 0.8226 - lr: 5.0000e-06
# Epoch 15/200
# 543/543 [==============================] - 65s 119ms/step - loss: 0.2370 - accuracy: 0.9276 - val_loss: 0.5332 - val_accuracy: 0.8205 - lr: 5.0000e-06
# Epoch 16/200
# 543/543 [==============================] - 65s 119ms/step - loss: 0.2286 - accuracy: 0.9276 - val_loss: 0.5069 - val_accuracy: 0.8226 - lr: 2.5000e-06
# Epoch 17/200
# 543/543 [==============================] - 65s 119ms/step - loss: 0.2230 - accuracy: 0.9276 - val_loss: 0.5013 - val_accuracy: 0.8205 - lr: 2.5000e-06
# Epoch 18/200
# 543/543 [==============================] - 65s 119ms/step - loss: 0.2176 - accuracy: 0.9335 - val_loss: 0.5098 - val_accuracy: 0.8247 - lr: 2.5000e-06
# Epoch 19/200
# 543/543 [==============================] - 64s 119ms/step - loss: 0.2135 - accuracy: 0.9351 - val_loss: 0.5196 - val_accuracy: 0.8185 - lr: 2.5000e-06
# Epoch 20/200
# 543/543 [==============================] - 65s 119ms/step - loss: 0.2104 - accuracy: 0.9363 - val_loss: 0.5235 - val_accuracy: 0.8340 - lr: 2.5000e-06
# Epoch 21/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2079 - accuracy: 0.9391 - val_loss: 0.5010 - val_accuracy: 0.8226 - lr: 1.2500e-06
# Epoch 22/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2126 - accuracy: 0.9359 - val_loss: 0.5095 - val_accuracy: 0.8278 - lr: 1.2500e-06
# Epoch 23/200
# 543/543 [==============================] - 64s 118ms/step - loss: 0.2083 - accuracy: 0.9373 - val_loss: 0.5532 - val_accuracy: 0.8195 - lr: 1.2500e-06
# Epoch 24/200
# 543/543 [==============================] - 64s 118ms/step - loss: 0.2055 - accuracy: 0.9384 - val_loss: 0.5215 - val_accuracy: 0.8195 - lr: 1.2500e-06
# Epoch 25/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2079 - accuracy: 0.9337 - val_loss: 0.5060 - val_accuracy: 0.8340 - lr: 1.2500e-06
# Epoch 26/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2046 - accuracy: 0.9398 - val_loss: 0.5261 - val_accuracy: 0.8257 - lr: 6.2500e-07
# Epoch 27/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2023 - accuracy: 0.9457 - val_loss: 0.4971 - val_accuracy: 0.8268 - lr: 6.2500e-07
# Epoch 28/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2017 - accuracy: 0.9416 - val_loss: 0.5106 - val_accuracy: 0.8288 - lr: 6.2500e-07
# Epoch 29/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2066 - accuracy: 0.9390 - val_loss: 0.5097 - val_accuracy: 0.8257 - lr: 6.2500e-07
# Epoch 30/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2009 - accuracy: 0.9407 - val_loss: 0.5220 - val_accuracy: 0.8309 - lr: 6.2500e-07
# Epoch 31/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2015 - accuracy: 0.9398 - val_loss: 0.5079 - val_accuracy: 0.8205 - lr: 3.1250e-07
# Epoch 32/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.1991 - accuracy: 0.9436 - val_loss: 0.5036 - val_accuracy: 0.8195 - lr: 3.1250e-07
# Epoch 33/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2019 - accuracy: 0.9402 - val_loss: 0.5375 - val_accuracy: 0.8257 - lr: 3.1250e-07
# Epoch 34/200
# 543/543 [==============================] - 64s 118ms/step - loss: 0.1987 - accuracy: 0.9406 - val_loss: 0.5283 - val_accuracy: 0.8361 - lr: 3.1250e-07
# Epoch 35/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.1997 - accuracy: 0.9413 - val_loss: 0.5060 - val_accuracy: 0.8268 - lr: 3.1250e-07
# Epoch 36/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.1957 - accuracy: 0.9440 - val_loss: 0.5292 - val_accuracy: 0.8340 - lr: 1.5625e-07
# Epoch 37/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.1961 - accuracy: 0.9443 - val_loss: 0.5213 - val_accuracy: 0.8309 - lr: 1.5625e-07
# Epoch 38/200
# 543/543 [==============================] - 63s 117ms/step - loss: 0.1975 - accuracy: 0.9390 - val_loss: 0.5151 - val_accuracy: 0.8351 - lr: 1.5625e-07
# Epoch 39/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.2006 - accuracy: 0.9450 - val_loss: 0.5136 - val_accuracy: 0.8330 - lr: 1.5625e-07
# Epoch 40/200
# 543/543 [==============================] - 64s 119ms/step - loss: 0.2016 - accuracy: 0.9393 - val_loss: 0.5204 - val_accuracy: 0.8288 - lr: 1.5625e-07
# Epoch 41/200
# 543/543 [==============================] - 64s 118ms/step - loss: 0.1995 - accuracy: 0.9433 - val_loss: 0.5116 - val_accuracy: 0.8205 - lr: 7.8125e-08
# Epoch 42/200
# 543/543 [==============================] - 64s 118ms/step - loss: 0.2000 - accuracy: 0.9383 - val_loss: 0.5299 - val_accuracy: 0.8174 - lr: 7.8125e-08
# Epoch 43/200
# 543/543 [==============================] - 63s 117ms/step - loss: 0.1974 - accuracy: 0.9457 - val_loss: 0.5089 - val_accuracy: 0.8195 - lr: 7.8125e-08
# Epoch 44/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.1963 - accuracy: 0.9443 - val_loss: 0.5281 - val_accuracy: 0.8268 - lr: 7.8125e-08
# Epoch 45/200
# 543/543 [==============================] - 64s 118ms/step - loss: 0.2006 - accuracy: 0.9435 - val_loss: 0.5092 - val_accuracy: 0.8278 - lr: 7.8125e-08
# Epoch 46/200
# 543/543 [==============================] - 63s 117ms/step - loss: 0.1995 - accuracy: 0.9401 - val_loss: 0.5234 - val_accuracy: 0.8330 - lr: 3.9062e-08
# Epoch 47/200
# 543/543 [==============================] - 64s 118ms/step - loss: 0.2008 - accuracy: 0.9384 - val_loss: 0.5314 - val_accuracy: 0.8268 - lr: 3.9062e-08
# Epoch 48/200
# 543/543 [==============================] - 63s 117ms/step - loss: 0.1976 - accuracy: 0.9402 - val_loss: 0.5147 - val_accuracy: 0.8268 - lr: 3.9062e-08
# Epoch 49/200
# 543/543 [==============================] - 63s 117ms/step - loss: 0.1975 - accuracy: 0.9428 - val_loss: 0.5059 - val_accuracy: 0.8268 - lr: 3.9062e-08
# Epoch 50/200
# 543/543 [==============================] - 64s 118ms/step - loss: 0.1930 - accuracy: 0.9479 - val_loss: 0.5158 - val_accuracy: 0.8185 - lr: 3.9062e-08
# Epoch 51/200
# 543/543 [==============================] - 65s 119ms/step - loss: 0.2010 - accuracy: 0.9456 - val_loss: 0.5030 - val_accuracy: 0.8320 - lr: 1.9531e-08
# Epoch 52/200
# 543/543 [==============================] - 65s 121ms/step - loss: 0.1939 - accuracy: 0.9434 - val_loss: 0.5021 - val_accuracy: 0.8278 - lr: 1.9531e-08
# Epoch 53/200
# 543/543 [==============================] - 64s 117ms/step - loss: 0.1977 - accuracy: 0.9420 - val_loss: 0.5128 - val_accuracy: 0.8237 - lr: 1.9531e-08
# Epoch 54/200
# 543/543 [==============================] - 64s 119ms/step - loss: 0.1955 - accuracy: 0.9448 - val_loss: 0.5081 - val_accuracy: 0.8237 - lr: 1.9531e-08

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='EfficientNet V2 L Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='EfficientNet V2 L Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the best model
ft2_model.save('/kaggle/working/FineTuningModelEfficientNetL')

# %%
# Predict labels for the entire test set (augmented)
X_test = preprocess_input(X_test*255)
predictions = ft2_model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(('healthy','unhealthy')), yticklabels=list(('healthy','unhealthy')), cmap='Blues', annot=True)
plt.title('Predictions of the augmented test set')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (1071, 2)
# Accuracy: 0.8245
# Precision: 0.8226
# Recall: 0.8178
# F1: 0.8198
