# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Fix randomness and hide warnings
seed = 164

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# Import tensorflow
import tensorflow as tf

from tensorflow import keras as tfk
from keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)

# Import other libraries
import cv2
from keras.applications.efficientnet_v2 import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import seaborn as sns
from PIL import Image
import pandas as pd
# Out:
# 2.13.0

# %%
data = np.load('/kaggle/input/challenge/dataset_refined.npz', allow_pickle=True)

images = data['arr_0']
labels = data['arr_1']
labels = np.array(labels)
images = np.array(images)

# %%
from imblearn.over_sampling import SMOTE
# Solve class imbalance using SMOTE
# Initialize the SMOTE object
smote = SMOTE(sampling_strategy=0.75, random_state=seed)

# Flatten the images
images_flat = images.reshape(images.shape[0], -1)  # Reshape to (num_samples, num_features)

# Now you can use SMOTE on 'images_flat'
images_smote, labels_smote = smote.fit_resample(images_flat, labels)


# Now, 'images_smote' and 'labels_smote' contain the oversampled dataset

#reshape the images

original_shape = (96, 96, 3)

images_original_shape = images_smote.reshape(-1, *original_shape)

# %%
# Needed for next step
images_balanced = images_original_shape
labels_balanced = labels_smote

# %%
# Show the data
# Number of images to display
size = labels_balanced.size
num_img = 10
# Create a random index to display every time a different set of images
random_index = np.random.rand()
random_index = int(random_index*(size-num_img))

# Create subplots for displaying items
fig, axes = plt.subplots(2, num_img//2, figsize=(20, 9))
for i in range(random_index, random_index + num_img):
    title = 'true label: ' + str(labels_balanced[i]) + ' index: ' + str(i)
    ax = axes[i%2, i%num_img//2]
    ax.set_title(title)
    ax.imshow(np.clip(images_balanced[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
print('Dataset campionato: ' + str(labels_balanced.size))
print('Dataset originale: ' + str(labels.size))
counts, unique = np.unique(labels_balanced, return_counts = True)
for i in range(counts.size):
  print(counts[i] + ': ' + str(unique[i]))
# Out:
# Dataset campionato: 5355
# Dataset originale: 4850
# healthy: 3060
# unhealthy: 2295

# %%
# Assuming 'labels_balanced' is a NumPy array containing your categorical labels
labels_onehot = labels_balanced  # Replace with your actual labels

# Get the unique categories in your label array
unique_categories = np.unique(labels_onehot)

# Initialize an empty array for one-hot encoded labels
one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

# Create one-hot encoded labels
for i, category in enumerate(unique_categories):
    one_hot_labels[:, i] = (labels_onehot == category).astype(int)

# Now, 'one_hot_labels' contains the one-hot encoded labels

labels_balanced_onehot = one_hot_labels

# %%
# Define a function to perform MixUp on the dataset
def mixup_data(X, y, alpha=0.2):
    mixed_X = []
    mixed_y = []

    for i in range(len(X)):
        # Randomly select another sample to mix with
        j = np.random.randint(len(X))

        # Randomly select a mixing ratio from a beta distribution
        beta = np.random.beta(alpha, alpha)

        mixed_X.append((X[i] * beta) + (X[j] * (1 - beta)))
        mixed_y.append((y[i] * beta) + (y[j] * (1 - beta)))

    mixed_X = np.array(mixed_X)
    mixed_y = np.array(mixed_y)

    return mixed_X, mixed_y

# Perform MixUp on your training data
images_augmented, labels_augmented_onehot = mixup_data(images_balanced, labels_balanced_onehot, alpha=0.2)

# %%
# PREPARE FOR NEXT LAYER
labels_augmented = labels_augmented_onehot
images_augmented = images_augmented

# %%
from sklearn.utils import shuffle
# Concatenate the original dataset with the mixup dataset
augmented_images_conc = np.concatenate((images_balanced, images_augmented), axis=0)
augmented_labels_conc = np.concatenate((labels_balanced_onehot, labels_augmented), axis=0)

# Shuffle the concatenated dataset
augmented_images_conc, augmented_labels_conc = shuffle(augmented_images_conc, augmented_labels_conc, random_state=seed)

#to make sure the next blocks work
images_augmented_2 = augmented_images_conc
labels_augmented_2 = augmented_labels_conc

# %%
# Assuming 'labels_balanced' is a NumPy array containing your categorical labels
labels_onehot = labels_balanced  # Replace with your actual labels

# Get the unique categories in your label array
unique_categories = np.unique(labels_onehot)

# Initialize an empty array for one-hot encoded labels
one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

# Create one-hot encoded labels
for i, category in enumerate(unique_categories):
    one_hot_labels[:, i] = (labels_onehot == category).astype(int)

# Now, 'one_hot_labels' contains the one-hot encoded labels

labels_balanced_onehot = one_hot_labels

# %%
def cutmix(images, labels, beta=1.0):
    """
    Apply CutMix data augmentation to a dataset.

    Args:
    images (numpy.ndarray): An array of images with shape (num_samples, height, width, channels).
    labels (numpy.ndarray): An array of labels with shape (num_samples, num_classes).
    beta (float): CutMix hyperparameter (default is 1.0).

    Returns:
    mixed_images (numpy.ndarray): Mixed images.
    mixed_labels (numpy.ndarray): Mixed labels.
    """
    num_samples, height, width, channels = images.shape

    # Randomly choose another sample to cut and mix with
    indices = np.arange(num_samples)
    np.random.shuffle(indices)
    mixed_images = images.copy()
    mixed_labels = labels.copy()

    for i in range(num_samples):
        j = indices[i]
        lam = np.random.beta(beta, beta)
        x, y, h, w = get_random_bbox(width, height, lam)
        mixed_images[i, y:y+h, x:x+w, :] = images[j, y:y+h, x:x+w, :]
        lam = 1 - (w * h / (width * height))
        mixed_labels[i] = lam * labels[i] + (1 - lam) * labels[j]

    return mixed_images, mixed_labels

def get_random_bbox(width, height, lam):
    r_x = np.random.randint(width)
    r_y = np.random.randint(height)
    r_w = int(width * np.sqrt(1 - lam))
    r_h = int(height * np.sqrt(1 - lam))
    x1 = np.clip(r_x - r_w // 2, 0, width)
    y1 = np.clip(r_y - r_h // 2, 0, height)
    x2 = np.clip(r_x + r_w // 2, 0, width)
    y2 = np.clip(r_y + r_h // 2, 0, height)
    return x1, y1, x2 - x1, y2 - y1

# Example usage:
# Assuming 'images' is your image dataset and 'labels' are the corresponding labels
images_augmented, labels_augmented_onehot = cutmix(images_balanced, labels_balanced_onehot, beta=1.0)

# %%
#PREPARE FOR NEXT LAYER
labels_augmented = labels_augmented_onehot
images_augmented = images_augmented

# %%
from sklearn.utils import shuffle
# Concatenate the original dataset with the mixup dataset
augmented_images_conc = np.concatenate((images_augmented_2, images_augmented), axis=0)
augmented_labels_conc = np.concatenate((labels_augmented_2, labels_augmented), axis=0)

# Shuffle the concatenated dataset
augmented_images_conc, augmented_labels_conc = shuffle(augmented_images_conc, augmented_labels_conc, random_state=seed)

#to make sure the next blocks work
images_augmented = augmented_images_conc
labels_augmented = augmented_labels_conc

# %%
if labels_augmented.ndim == 1:
  print("eseguendo onehot\n")

  # Assuming 'labels_balanced' is a NumPy array containing your categorical labels
  labels_onehot = labels_augmented  # Replace with your actual labels

  # Get the unique categories in your label array
  unique_categories = np.unique(labels_onehot)

  # Initialize an empty array for one-hot encoded labels
  one_hot_labels = np.zeros((len(labels_onehot), len(unique_categories)))

  # Create one-hot encoded labels
  for i, category in enumerate(unique_categories):
     one_hot_labels[:, i] = (labels_onehot == category).astype(int)

  # Now, 'one_hot_labels' contains the one-hot encoded labels

  labels_augmented_onehot = one_hot_labels


else:
  print("one-hot già eseguito\n")

  labels_augmented_onehot = labels_augmented
# Out:
# one-hot già eseguito

# %%
# We applied both CutMix and MixUp to the dataset

# %%
# We are going to divide the dataset into two additional partitions, one to be used only for the transfer learning phase and the 
# other only for the fine tuning phase
X = images_augmented
y = labels_augmented_onehot
# Split data into train_val and test sets
X_tl, X_ft, y_tl, y_ft = train_test_split(X, y, random_state=seed, test_size=.40, stratify=np.argmax(y,axis=1))

# Print shapes of the datasets
print(f"X_transfer_learning: {X_tl.shape}, y_transfer_learning: {y_tl.shape}")
print(f"X_fine_tuning: {X_ft.shape}, y_fine_tuning: {y_ft.shape}")
# Out:
# X_transfer_learning: (9639, 96, 96, 3), y_transfer_learning: (9639, 2)
# X_fine_tuning: (6426, 96, 96, 3), y_fine_tuning: (6426, 2)

# %%
# Split the dataset dedicated to the transfer learning phase into train, test and validation sets
X = X_tl
y = y_tl
# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=.05, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=.15, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (7783, 96, 96, 3), y_train shape: (7783, 2)
# X_val shape: (1374, 96, 96, 3), y_val shape: (1374, 2)
# X_test shape: (482, 96, 96, 3), y_test shape: (482, 2)

# %%
# Performa image augmentation before training
preprocessing = tf.keras.Sequential([
          tfkl.RandomBrightness(0.2, (0,1)),
          tfkl.RandomRotation(0.2),
          tfkl.RandomFlip("horizontal"),
      ], name='preprocessing_efficientNet')
    
X_train = preprocessing(X_train)
X_val = preprocessing(X_val)
X_test = preprocessing(X_test)

# %%
#EfficientNetV2M
efficientnet = tfk.applications.EfficientNetV2M(
    include_top=False,
    weights="imagenet",
    pooling='avg',
    classes=2,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 1s 0us/step

# %%
from tensorflow.keras.regularizers import l2

def build_efficientnet():
    '''# Image augmentation
    preprocessing = tf.keras.Sequential([
          tfkl.RandomBrightness(0.2, (0,1)),
          tfkl.RandomRotation(0.2),
          tfkl.RandomFlip("horizontal"),
      ], name='preprocessing_efficientNet') '''

# Use the supernet as feature extractor, i.e. freeze all its weigths
    efficientnet.trainable = False

# Create an input layer with shape (96, 96, 3)
    inputs = tfk.Input(shape=(96, 96, 3))

# Connect MobileNetV2 to the input
    x = efficientnet(inputs)

#Hyperparameters obtained using the tuner library
# Dense layer with regularizer between mobile net and batch
  #x = tfkl.Dense(units=hp.Int("units", min_value=32, max_value=512, step=32),
                 #kernel_regularizer=l2(0.01))(x)
    x = tfkl.Dense(1280, activation='relu')(x)
#x = tfkl.Dense(1280, activation='relu')(x)

# Add Batch Normalization
    x = tfkl.BatchNormalization(epsilon=1e-06, momentum=0.9, weights=None)(x)

# Dense layer between batch and dropout with regularizer
    x = tfkl.Dense(640, activation='relu')(x)
#x = tfkl.Dense(640, activation='relu')(x)

# Add a Dropout layer with 0.4
    x = tfkl.Dropout(0.7)(x)

# Add a Dense layer with 2 units and softmax activation as the classifier
    outputs = tfkl.Dense(2, activation='softmax')(x)

# Create a Model connecting input and output
    tl2_model = tfk.Model(inputs=inputs, outputs=outputs, name='model_efficientnet')


    return tl2_model

# %%
tl2_model = build_efficientnet()
# Compile the model with Categorical Cross-Entropy loss and Adam optimizer
tl2_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])

# %%
# Train the model
history = tl2_model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)]
).history
# Out:
# Epoch 1/200
# 487/487 [==============================] - 52s 49ms/step - loss: 1.1765 - accuracy: 0.6402 - val_loss: 0.5730 - val_accuracy: 0.7227 - lr: 0.0010
# Epoch 2/200
# 487/487 [==============================] - 17s 34ms/step - loss: 0.6404 - accuracy: 0.6877 - val_loss: 0.5624 - val_accuracy: 0.7278 - lr: 0.0010
# Epoch 3/200
# 487/487 [==============================] - 17s 34ms/step - loss: 0.5961 - accuracy: 0.7042 - val_loss: 0.5247 - val_accuracy: 0.7606 - lr: 0.0010
# Epoch 4/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.5801 - accuracy: 0.7122 - val_loss: 0.5293 - val_accuracy: 0.7438 - lr: 0.0010
# Epoch 5/200
# 487/487 [==============================] - 17s 34ms/step - loss: 0.5607 - accuracy: 0.7313 - val_loss: 0.5223 - val_accuracy: 0.7620 - lr: 0.0010
# Epoch 6/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.5540 - accuracy: 0.7370 - val_loss: 0.5526 - val_accuracy: 0.7540 - lr: 0.0010
# Epoch 7/200
# 487/487 [==============================] - 17s 34ms/step - loss: 0.5493 - accuracy: 0.7311 - val_loss: 0.5031 - val_accuracy: 0.7795 - lr: 0.0010
# Epoch 8/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.5420 - accuracy: 0.7396 - val_loss: 0.5796 - val_accuracy: 0.7322 - lr: 0.0010
# Epoch 9/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.5376 - accuracy: 0.7407 - val_loss: 0.5389 - val_accuracy: 0.7387 - lr: 0.0010
# Epoch 10/200
# 487/487 [==============================] - 16s 34ms/step - loss: 0.5348 - accuracy: 0.7475 - val_loss: 0.5282 - val_accuracy: 0.7766 - lr: 0.0010
# Epoch 11/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.5321 - accuracy: 0.7425 - val_loss: 0.5282 - val_accuracy: 0.7627 - lr: 0.0010
# Epoch 12/200
# 487/487 [==============================] - 16s 34ms/step - loss: 0.5240 - accuracy: 0.7516 - val_loss: 0.5354 - val_accuracy: 0.7569 - lr: 0.0010
# Epoch 13/200
# 487/487 [==============================] - 17s 34ms/step - loss: 0.4938 - accuracy: 0.7703 - val_loss: 0.5104 - val_accuracy: 0.7846 - lr: 1.0000e-04
# Epoch 14/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4808 - accuracy: 0.7794 - val_loss: 0.4987 - val_accuracy: 0.7838 - lr: 1.0000e-04
# Epoch 15/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4767 - accuracy: 0.7859 - val_loss: 0.5122 - val_accuracy: 0.7838 - lr: 1.0000e-04
# Epoch 16/200
# 487/487 [==============================] - 17s 34ms/step - loss: 0.4803 - accuracy: 0.7804 - val_loss: 0.5038 - val_accuracy: 0.7889 - lr: 1.0000e-04
# Epoch 17/200
# 487/487 [==============================] - 16s 34ms/step - loss: 0.4730 - accuracy: 0.7850 - val_loss: 0.5078 - val_accuracy: 0.7940 - lr: 1.0000e-04
# Epoch 18/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4666 - accuracy: 0.7835 - val_loss: 0.5170 - val_accuracy: 0.7868 - lr: 1.0000e-04
# Epoch 19/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4641 - accuracy: 0.7940 - val_loss: 0.5032 - val_accuracy: 0.7846 - lr: 1.0000e-04
# Epoch 20/200
# 487/487 [==============================] - 16s 34ms/step - loss: 0.4595 - accuracy: 0.7948 - val_loss: 0.4998 - val_accuracy: 0.7918 - lr: 1.0000e-05
# Epoch 21/200
# 487/487 [==============================] - 16s 34ms/step - loss: 0.4580 - accuracy: 0.8010 - val_loss: 0.5012 - val_accuracy: 0.7926 - lr: 1.0000e-05
# Epoch 22/200
# 487/487 [==============================] - 16s 34ms/step - loss: 0.4542 - accuracy: 0.7970 - val_loss: 0.4936 - val_accuracy: 0.7918 - lr: 1.0000e-05
# Epoch 23/200
# 487/487 [==============================] - 17s 34ms/step - loss: 0.4550 - accuracy: 0.7944 - val_loss: 0.4936 - val_accuracy: 0.7955 - lr: 1.0000e-05
# Epoch 24/200
# 487/487 [==============================] - 16s 34ms/step - loss: 0.4536 - accuracy: 0.7953 - val_loss: 0.5045 - val_accuracy: 0.7918 - lr: 1.0000e-05
# Epoch 25/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4548 - accuracy: 0.7964 - val_loss: 0.5013 - val_accuracy: 0.7889 - lr: 1.0000e-05
# Epoch 26/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4524 - accuracy: 0.7946 - val_loss: 0.5039 - val_accuracy: 0.7918 - lr: 1.0000e-05
# Epoch 27/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4499 - accuracy: 0.8015 - val_loss: 0.5085 - val_accuracy: 0.7926 - lr: 1.0000e-05
# Epoch 28/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4493 - accuracy: 0.7956 - val_loss: 0.4996 - val_accuracy: 0.7955 - lr: 1.0000e-06
# Epoch 29/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4527 - accuracy: 0.8017 - val_loss: 0.5036 - val_accuracy: 0.7926 - lr: 1.0000e-06
# Epoch 30/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4488 - accuracy: 0.7952 - val_loss: 0.5056 - val_accuracy: 0.7904 - lr: 1.0000e-06
# Epoch 31/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4483 - accuracy: 0.8003 - val_loss: 0.5045 - val_accuracy: 0.7940 - lr: 1.0000e-06
# Epoch 32/200
# 487/487 [==============================] - 16s 33ms/step - loss: 0.4535 - accuracy: 0.7937 - val_loss: 0.5037 - val_accuracy: 0.7897 - lr: 1.0000e-06
# Epoch 33/200
# 487/487 [==============================] - 17s 34ms/step - loss: 0.4517 - accuracy: 0.7974 - val_loss: 0.5090 - val_accuracy: 0.7940 - lr: 1.0000e-07

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='EfficientNet V2 M Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='EfficientNet V2 M Transfer Learning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
tl2_model.save('/kaggle/working/TransferLearningModelEfficientNetM')

# %%
# Predict labels for the entire test set (augmented)
X_test = preprocess_input(X_test*255)
predictions = tl2_model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(('healthy','unhealthy')), yticklabels=list(('healthy','unhealthy')), cmap='Blues', annot=True)
plt.title('Predictions of the augmented test set')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (482, 2)
# Accuracy: 0.7697
# Precision: 0.7706
# Recall: 0.7563
# F1: 0.76

# %%
# Split the dataset dedicated to the fine tuning into train, validation and test
X = X_ft
y = y_ft
# Split data into train_val and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, random_state=seed, test_size=.05, stratify=np.argmax(y,axis=1))

# Further split train_val into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed, test_size=.20, stratify=np.argmax(y_train_val,axis=1))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (4883, 96, 96, 3), y_train shape: (4883, 2)
# X_val shape: (1221, 96, 96, 3), y_val shape: (1221, 2)
# X_test shape: (322, 96, 96, 3), y_test shape: (322, 2)

# %%
# Perform image augmentation before training
preprocessing = tf.keras.Sequential([
          tfkl.RandomBrightness(0.2, (0,1)),
          tfkl.RandomRotation(0.2),
          tfkl.RandomFlip("horizontal"),
      ], name='preprocessing_efficientNet')
    
X_train = preprocessing(X_train)
X_val = preprocessing(X_val)
X_test = preprocessing(X_test)

# %%
# Re-load the model after transfer learning
ft2_model = tf.keras.models.load_model('/kaggle/working/TransferLearningModelEfficientNetM')
del tl2_model

#ft2_model = build_efficientnet()
ft2_model.summary()

# Set all MobileNetV2 layers as trainable
ft2_model.get_layer('efficientnetv2-m').trainable = True
# Out:
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-m (Function  (None, 1280)              53150388
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  dropout (Dropout)           (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 55616310 (212.16 MB)
# Trainable params: 2463362 (9.40 MB)
# Non-trainable params: 53152948 (202.76 MB)
# _________________________________________________________________

# %%
# Freeze first N layers, e.g., until the 133rd one
#meno layer??
#N = 71
N = 380
for i, layer in enumerate(ft2_model.get_layer('efficientnetv2-m').layers[:N]):
  layer.trainable=False
ft2_model.summary()

ft2_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-5), metrics=['accuracy'])
# Out:
# Model: "model_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetv2-m (Function  (None, 1280)              53150388
#  al)
#
#  dense (Dense)               (None, 1280)              1639680
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense_1 (Dense)             (None, 640)               819840
#
#  dropout (Dropout)           (None, 640)               0
#
#  dense_2 (Dense)             (None, 2)                 1282
#
# =================================================================
# Total params: 55616310 (212.16 MB)
# Trainable params: 45925714 (175.19 MB)
# Non-trainable params: 9690596 (36.97 MB)
# _________________________________________________________________

# %%
# Fine-tune the model
history = ft2_model.fit(
    x = preprocess_input(X_train*255), 
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val), 
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True),
                 tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)]
).history
# Out:
# Epoch 1/200
# 306/306 [==============================] - 106s 106ms/step - loss: 0.7467 - accuracy: 0.6504 - val_loss: 0.6518 - val_accuracy: 0.6912 - lr: 1.0000e-05
# Epoch 2/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.6071 - accuracy: 0.7043 - val_loss: 0.6070 - val_accuracy: 0.7150 - lr: 1.0000e-05
# Epoch 3/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.5609 - accuracy: 0.7205 - val_loss: 0.6036 - val_accuracy: 0.7281 - lr: 1.0000e-05
# Epoch 4/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.5245 - accuracy: 0.7518 - val_loss: 0.5497 - val_accuracy: 0.7445 - lr: 1.0000e-05
# Epoch 5/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.4952 - accuracy: 0.7782 - val_loss: 0.5646 - val_accuracy: 0.7658 - lr: 1.0000e-05
# Epoch 6/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.4641 - accuracy: 0.7987 - val_loss: 0.5305 - val_accuracy: 0.7584 - lr: 1.0000e-05
# Epoch 7/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.4425 - accuracy: 0.8083 - val_loss: 0.5310 - val_accuracy: 0.7666 - lr: 1.0000e-05
# Epoch 8/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.4168 - accuracy: 0.8212 - val_loss: 0.5478 - val_accuracy: 0.7592 - lr: 1.0000e-05
# Epoch 9/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.3879 - accuracy: 0.8466 - val_loss: 0.5768 - val_accuracy: 0.7821 - lr: 1.0000e-05
# Epoch 10/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.3883 - accuracy: 0.8468 - val_loss: 0.5560 - val_accuracy: 0.7846 - lr: 1.0000e-05
# Epoch 11/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3530 - accuracy: 0.8728 - val_loss: 0.5582 - val_accuracy: 0.7658 - lr: 1.0000e-05
# Epoch 12/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3369 - accuracy: 0.8847 - val_loss: 0.5926 - val_accuracy: 0.7715 - lr: 1.0000e-06
# Epoch 13/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3359 - accuracy: 0.8734 - val_loss: 0.5570 - val_accuracy: 0.7764 - lr: 1.0000e-06
# Epoch 14/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3334 - accuracy: 0.8798 - val_loss: 0.5760 - val_accuracy: 0.7838 - lr: 1.0000e-06
# Epoch 15/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3283 - accuracy: 0.8806 - val_loss: 0.5973 - val_accuracy: 0.7789 - lr: 1.0000e-06
# Epoch 16/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3473 - accuracy: 0.8669 - val_loss: 0.5822 - val_accuracy: 0.7797 - lr: 1.0000e-06
# Epoch 17/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3240 - accuracy: 0.8855 - val_loss: 0.5852 - val_accuracy: 0.7723 - lr: 1.0000e-07
# Epoch 18/200
# 306/306 [==============================] - 28s 90ms/step - loss: 0.3427 - accuracy: 0.8720 - val_loss: 0.5587 - val_accuracy: 0.7871 - lr: 1.0000e-07
# Epoch 19/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3392 - accuracy: 0.8779 - val_loss: 0.5613 - val_accuracy: 0.7821 - lr: 1.0000e-07
# Epoch 20/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3256 - accuracy: 0.8818 - val_loss: 0.5604 - val_accuracy: 0.7871 - lr: 1.0000e-07
# Epoch 21/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3292 - accuracy: 0.8808 - val_loss: 0.5546 - val_accuracy: 0.7731 - lr: 1.0000e-07
# Epoch 22/200
# 306/306 [==============================] - 27s 90ms/step - loss: 0.3351 - accuracy: 0.8761 - val_loss: 0.5838 - val_accuracy: 0.7756 - lr: 1.0000e-08
# Epoch 23/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3177 - accuracy: 0.8818 - val_loss: 0.5600 - val_accuracy: 0.7830 - lr: 1.0000e-08
# Epoch 24/200
# 306/306 [==============================] - 27s 90ms/step - loss: 0.3385 - accuracy: 0.8814 - val_loss: 0.5759 - val_accuracy: 0.7781 - lr: 1.0000e-08
# Epoch 25/200
# 306/306 [==============================] - 27s 90ms/step - loss: 0.3245 - accuracy: 0.8790 - val_loss: 0.5759 - val_accuracy: 0.7854 - lr: 1.0000e-08
# Epoch 26/200
# 306/306 [==============================] - 28s 90ms/step - loss: 0.3303 - accuracy: 0.8781 - val_loss: 0.5644 - val_accuracy: 0.7895 - lr: 1.0000e-08
# Epoch 27/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3221 - accuracy: 0.8800 - val_loss: 0.5501 - val_accuracy: 0.7805 - lr: 1.0000e-09
# Epoch 28/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3258 - accuracy: 0.8841 - val_loss: 0.5649 - val_accuracy: 0.7789 - lr: 1.0000e-09
# Epoch 29/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.3253 - accuracy: 0.8898 - val_loss: 0.5760 - val_accuracy: 0.7781 - lr: 1.0000e-09
# Epoch 30/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3195 - accuracy: 0.8824 - val_loss: 0.5638 - val_accuracy: 0.7789 - lr: 1.0000e-09
# Epoch 31/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3200 - accuracy: 0.8870 - val_loss: 0.6439 - val_accuracy: 0.7772 - lr: 1.0000e-09
# Epoch 32/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3175 - accuracy: 0.8898 - val_loss: 0.5756 - val_accuracy: 0.7772 - lr: 1.0000e-10
# Epoch 33/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3187 - accuracy: 0.8898 - val_loss: 0.5978 - val_accuracy: 0.7740 - lr: 1.0000e-10
# Epoch 34/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3280 - accuracy: 0.8874 - val_loss: 0.5923 - val_accuracy: 0.7821 - lr: 1.0000e-10
# Epoch 35/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.3228 - accuracy: 0.8892 - val_loss: 0.5707 - val_accuracy: 0.7813 - lr: 1.0000e-10
# Epoch 36/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3258 - accuracy: 0.8800 - val_loss: 0.5787 - val_accuracy: 0.7772 - lr: 1.0000e-10
# Epoch 37/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3236 - accuracy: 0.8835 - val_loss: 0.5652 - val_accuracy: 0.7887 - lr: 1.0000e-11
# Epoch 38/200
# 306/306 [==============================] - 26s 87ms/step - loss: 0.3134 - accuracy: 0.8886 - val_loss: 0.5991 - val_accuracy: 0.7740 - lr: 1.0000e-11
# Epoch 39/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.3334 - accuracy: 0.8818 - val_loss: 0.5630 - val_accuracy: 0.7944 - lr: 1.0000e-11
# Epoch 40/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3197 - accuracy: 0.8841 - val_loss: 0.5485 - val_accuracy: 0.7838 - lr: 1.0000e-11
# Epoch 41/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3297 - accuracy: 0.8741 - val_loss: 0.5416 - val_accuracy: 0.7887 - lr: 1.0000e-11
# Epoch 42/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3310 - accuracy: 0.8775 - val_loss: 0.5571 - val_accuracy: 0.7756 - lr: 1.0000e-12
# Epoch 43/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3299 - accuracy: 0.8808 - val_loss: 0.5422 - val_accuracy: 0.7813 - lr: 1.0000e-12
# Epoch 44/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3271 - accuracy: 0.8880 - val_loss: 0.5588 - val_accuracy: 0.7731 - lr: 1.0000e-12
# Epoch 45/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3314 - accuracy: 0.8841 - val_loss: 0.5398 - val_accuracy: 0.7789 - lr: 1.0000e-12
# Epoch 46/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3244 - accuracy: 0.8802 - val_loss: 0.5524 - val_accuracy: 0.7805 - lr: 1.0000e-12
# Epoch 47/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3243 - accuracy: 0.8812 - val_loss: 0.5707 - val_accuracy: 0.7756 - lr: 1.0000e-13
# Epoch 48/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3287 - accuracy: 0.8812 - val_loss: 0.5543 - val_accuracy: 0.7879 - lr: 1.0000e-13
# Epoch 49/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3246 - accuracy: 0.8849 - val_loss: 0.5900 - val_accuracy: 0.7633 - lr: 1.0000e-13
# Epoch 50/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3294 - accuracy: 0.8784 - val_loss: 0.5474 - val_accuracy: 0.7797 - lr: 1.0000e-13
# Epoch 51/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3260 - accuracy: 0.8804 - val_loss: 0.6035 - val_accuracy: 0.7740 - lr: 1.0000e-13
# Epoch 52/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.3223 - accuracy: 0.8794 - val_loss: 0.5552 - val_accuracy: 0.7952 - lr: 1.0000e-14
# Epoch 53/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3240 - accuracy: 0.8784 - val_loss: 0.5618 - val_accuracy: 0.7781 - lr: 1.0000e-14
# Epoch 54/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3292 - accuracy: 0.8853 - val_loss: 0.5663 - val_accuracy: 0.7781 - lr: 1.0000e-14
# Epoch 55/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3241 - accuracy: 0.8769 - val_loss: 0.5900 - val_accuracy: 0.7764 - lr: 1.0000e-14
# Epoch 56/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3310 - accuracy: 0.8816 - val_loss: 0.5599 - val_accuracy: 0.7895 - lr: 1.0000e-14
# Epoch 57/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3349 - accuracy: 0.8824 - val_loss: 0.5791 - val_accuracy: 0.7805 - lr: 1.0000e-15
# Epoch 58/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3323 - accuracy: 0.8743 - val_loss: 0.5692 - val_accuracy: 0.7821 - lr: 1.0000e-15
# Epoch 59/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3195 - accuracy: 0.8841 - val_loss: 0.5636 - val_accuracy: 0.7821 - lr: 1.0000e-15
# Epoch 60/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3275 - accuracy: 0.8784 - val_loss: 0.5837 - val_accuracy: 0.7731 - lr: 1.0000e-15
# Epoch 61/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.3187 - accuracy: 0.8853 - val_loss: 0.6032 - val_accuracy: 0.7756 - lr: 1.0000e-15
# Epoch 62/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.3171 - accuracy: 0.8876 - val_loss: 0.5383 - val_accuracy: 0.7912 - lr: 1.0000e-16
# Epoch 63/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3265 - accuracy: 0.8833 - val_loss: 0.5880 - val_accuracy: 0.7781 - lr: 1.0000e-16
# Epoch 64/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3262 - accuracy: 0.8851 - val_loss: 0.5537 - val_accuracy: 0.7830 - lr: 1.0000e-16
# Epoch 65/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3349 - accuracy: 0.8800 - val_loss: 0.5938 - val_accuracy: 0.7748 - lr: 1.0000e-16
# Epoch 66/200
# 306/306 [==============================] - 27s 88ms/step - loss: 0.3309 - accuracy: 0.8800 - val_loss: 0.5586 - val_accuracy: 0.7854 - lr: 1.0000e-16
# Epoch 67/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3274 - accuracy: 0.8806 - val_loss: 0.5645 - val_accuracy: 0.7764 - lr: 1.0000e-17
# Epoch 68/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3228 - accuracy: 0.8882 - val_loss: 0.5874 - val_accuracy: 0.7846 - lr: 1.0000e-17
# Epoch 69/200
# 306/306 [==============================] - 26s 86ms/step - loss: 0.3293 - accuracy: 0.8790 - val_loss: 0.5748 - val_accuracy: 0.7789 - lr: 1.0000e-17
# Epoch 70/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3215 - accuracy: 0.8890 - val_loss: 0.5546 - val_accuracy: 0.7797 - lr: 1.0000e-17
# Epoch 71/200
# 306/306 [==============================] - 27s 87ms/step - loss: 0.3307 - accuracy: 0.8880 - val_loss: 0.5658 - val_accuracy: 0.7772 - lr: 1.0000e-17
# Epoch 72/200
# 306/306 [==============================] - 27s 89ms/step - loss: 0.3287 - accuracy: 0.8771 - val_loss: 0.6157 - val_accuracy: 0.7781 - lr: 1.0000e-18

# %%
# Plot the training
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='EfficientNet V2 M Fine Tuning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='EfficientNet V2 M Fine Tuning', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the best model
ft2_model.save('/kaggle/working/FineTuningModelEfficientNetM')

# %%
# Predict labels for the entire test set (augmented)
X_test = preprocess_input(X_test*255)
predictions = ft2_model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(('healthy','unhealthy')), yticklabels=list(('healthy','unhealthy')), cmap='Blues', annot=True)
plt.title('Predictions of the augmented test set')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (322, 2)
# Accuracy: 0.823
# Precision: 0.8244
# Recall: 0.8131
# F1: 0.8168
